# %%
import re

import pandas as pd 
from langchain_community.vectorstores import FAISS

# %%
from neo4j import GraphDatabase
driver = GraphDatabase.driver("bolt://192.168.0.131:7687", auth=("cc", "Tt66668888."))
def execute_cypher(session, cypher_statement):
    session.run(cypher_statement)

# %%
import re
def sanitize_name(name):
    sanitized = re.sub(r'\W+', '_', name)
    if re.match(r'^\d', sanitized):
        sanitized = 'N_' + sanitized
    return sanitized

def create_cypher(file_name, sheet_name, df, tertiary_node_col):
    # 创建一级节点（文件名）
    cypher_file = f"MERGE (f:SourceFile {{name: '{sanitize_name(file_name)}'}})"
    
    # 创建二级节点（表格名称）并与一级节点关联
    cypher_sheet = f"""
    MERGE (s:SourceSheet {{name: '{sanitize_name(sheet_name)}'}})
    MERGE (s)-[:BELONGS_TO]->(f)
    """
    
    # 创建三级节点（定义的列的值）及其属性，并与二级节点关联
    relationships = []
    for index, row in df.iterrows():
        tertiary_node_value = row[tertiary_node_col]
        if pd.notna(tertiary_node_value) and tertiary_node_value != '':
            tertiary_node_name = sanitize_name(f"{tertiary_node_value}_{index}")
            relationships.append(f"""
            MERGE (t_{index}:{sanitize_name(tertiary_node_col)} {{name: '{tertiary_node_value}'}})
            MERGE (t_{index})-[:{sanitize_name(tertiary_node_col)}]->(s)
            """)
            for column, value in row.items():
                if column != tertiary_node_col and pd.notna(value) and value != '':
                    property_name = sanitize_name(column)
                    relationships.append(f"""
                    MERGE (p_{index}_{property_name}:{property_name} {{value: '{value}'}})
                    MERGE (t_{index})-[:{property_name}]->(p_{index}_{property_name})
                    """)
    
    # 组合所有 Cypher 语句
    cypher = cypher_file + cypher_sheet + ''.join(relationships)
    
    return cypher

# %%
product_sheets = ['SE预约+集控+虚拟分控（5间）','SE预约+集控+虚拟分控（40间）','SE预约+集控+硬件分控（40间）','SE仅预约含一键入会（20间）','SE仅预约无一键入会（40间）','ezCloud预约+集控+硬件分控（50间）','ezCloud仅预约无一键入会（100间）','SOFTAVC体验点','文体版WIFI（1间）','文体版5G（1间）']
with driver.session() as session:
    for num,sheet in enumerate(product_sheets):
        df = pd.read_excel('/mnt/d/project/zzbc/experiment_project/experiment_project/audio/data/audio/excloud/ezCloud.xlsx',sheet_name=sheet)
        cypher_statement = create_cypher(file_name='ez_cloud', sheet_name=sheet,df = df,tertiary_node_col='设备名称')
        
        execute_cypher(session, cypher_statement)
        print(f'完成入库 {sheet}   剩余  {len(sheets)-num}',)
# Out:
# 完成入库 SE预约+集控+虚拟分控（5间）   剩余  11
# 完成入库 SE预约+集控+虚拟分控（40间）   剩余  10
# 完成入库 SE预约+集控+硬件分控（40间）   剩余  9
# 完成入库 SE仅预约含一键入会（20间）   剩余  8
# 完成入库 SE仅预约无一键入会（40间）   剩余  7
# 完成入库 ezCloud预约+集控+硬件分控（50间）   剩余  6
# 完成入库 ezCloud仅预约无一键入会（100间）   剩余  5
# 完成入库 SOFTAVC体验点   剩余  4
# 完成入库 文体版WIFI（1间）   剩余  3
# 完成入库 文体版5G（1间）   剩余  2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       2 with driver.session() as session:
#       3     for num,sheet in enumerate(sheets):
# ----> 4         df = pd.read_excel('/mnt/d/project/zzbc/experiment_project/experiment_project/audio/data/audio/excloud/ezCloud.xlsx',sheet_name=sheet)
#       5         cypher_statement = create_cypher(file_name='ez_cloud', sheet_name=sheet,df = df,tertiary_node_col='设备名称')
#       7         execute_cypher(session, cypher_statement)
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/io/excel/_base.py:490, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#     489 try:
# --> 490     data = io.parse(
#     491         sheet_name=sheet_name,
#     492         header=header,
#     493         names=names,
#     494         index_col=index_col,
#     495         usecols=usecols,
#     496         squeeze=squeeze,
#     497         dtype=dtype,
#     498         converters=converters,
#     499         true_values=true_values,
#     500         false_values=false_values,
#     501         skiprows=skiprows,
#     502         nrows=nrows,
#     503         na_values=na_values,
#     504         keep_default_na=keep_default_na,
#     505         na_filter=na_filter,
#     506         verbose=verbose,
#     507         parse_dates=parse_dates,
#     508         date_parser=date_parser,
#     509         thousands=thousands,
#     510         decimal=decimal,
#     511         comment=comment,
#     512         skipfooter=skipfooter,
#     513         convert_float=convert_float,
#     514         mangle_dupe_cols=mangle_dupe_cols,
#     515     )
#     516 finally:
#     517     # make sure to close opened file handles
#     518     if should_close:
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/io/excel/_base.py:1734, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#    1700 def parse(
#    1701     self,
#    1702     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1721     **kwds,
#    1722 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1723     """
#    1724     Parse specified sheet(s) into a DataFrame.
#    1725
#    (...)
#    1732         DataFrame from the passed in Excel file.
#    1733     """
# -> 1734     return self._reader.parse(
#    1735         sheet_name=sheet_name,
#    1736         header=header,
#    1737         names=names,
#    1738         index_col=index_col,
#    1739         usecols=usecols,
#    1740         squeeze=squeeze,
#    1741         converters=converters,
#    1742         true_values=true_values,
#    1743         false_values=false_values,
#    1744         skiprows=skiprows,
#    1745         nrows=nrows,
#    1746         na_values=na_values,
#    1747         parse_dates=parse_dates,
#    1748         date_parser=date_parser,
#    1749         thousands=thousands,
#    1750         comment=comment,
#    1751         skipfooter=skipfooter,
#    1752         convert_float=convert_float,
#    1753         mangle_dupe_cols=mangle_dupe_cols,
#    1754         **kwds,
#    1755     )
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/io/excel/_base.py:760, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     757     print(f"Reading sheet {asheetname}")
#     759 if isinstance(asheetname, str):
# --> 760     sheet = self.get_sheet_by_name(asheetname)
#     761 else:  # assume an integer if not a string
#     762     sheet = self.get_sheet_by_index(asheetname)
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/io/excel/_openpyxl.py:577, in OpenpyxlReader.get_sheet_by_name(self, name)
#     576 def get_sheet_by_name(self, name: str):
# --> 577     self.raise_if_bad_sheet_by_name(name)
#     578     return self.book[name]
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/io/excel/_base.py:602, in BaseExcelReader.raise_if_bad_sheet_by_name(self, name)
#     600 def raise_if_bad_sheet_by_name(self, name: str) -> None:
#     601     if name not in self.sheet_names:
# --> 602         raise ValueError(f"Worksheet named '{name}' not found")
#
# ValueError: Worksheet named '' not found

# %%
plan_sheets = ['模板说明']
df = pd.read_excel('/mnt/d/project/zzbc/experiment_project/experiment_project/audio/data/audio/excloud/ezCloud.xlsx',sheet_name=plan_sheets[0])
df
# Out:
#                                 模板名称 ezCloud版本   适配房间数  \
# 0                            全套预约+集控       NaN     NaN
# 1                         SOFTAVC体验点     SaaS版      任意
# 2                   SE预约+集控+虚拟分控（5间）        SE   5~20间
# 3                  SE预约+集控+虚拟分控（40间）        SE  21~40间
# 4                  SE预约+集控+硬件分控（40间）        SE  40间及以下
# 5             ezCloud预约+集控+硬件分控（40间）       标准版      任意
# 6                                仅预约       NaN     NaN
# 7                    SE仅预约含一键入会（20间）        SE  40间及以下
# 8                    SE仅预约无一键入会（40间）        SE  40间及以下
# 9              ezCloud仅预约无一键入会（100间）       标准版      任意
# 10  仅集控，与全套预约+集控配置类似，去掉预约软件和CTS信息屏部分       NaN     NaN
# 11              SE仅集控+虚拟分控（5间），同全套5间        SE   5~20间
# 12          SE仅集控+虚拟分控（40间），同全套40间虚拟        SE  21~40间
# 13           SE仅集控+硬件分控（40间），同全套40间硬        SE  40间及以下
# 14                      仅控制，无预约、集控需求       NaN     NaN
# 15                          硬件分控（1间）         无      任意
# 16                       ezCloud文体方向       NaN     NaN
# 17              ezCloud文体版WIFI（1个场馆）       文体版      任意
# 18                ezCloud文体版5G（1个场馆）       文体版      任意
# 19                              其他资源       NaN     NaN
# 20                    ezCloud会议连接拓扑图       NaN     NaN
# 21                   ezCloud文体版连接拓扑图       NaN     NaN
# 22          ezCloud&SE&ips智能硬件产品参数表        NaN     NaN
# 23            ezCloud标底参数、功能说明及注意事项        NaN     NaN
#
#                              备注（注意事项）   预约   集控   分控 CS传感器 CTS控制屏 CTS信息屏  \
# 0                                 NaN  NaN  NaN  NaN   NaN    NaN    NaN
# 1   采用云端ezCloud SaaS版本，与DP120智慧中控物联系统    ✅    ✅    ✅     ✅      ✅      ✅
# 2               MS100作为虚拟分控和SE主机，性价比高    ✅    ✅   ✅虚     ✅      ✅      ✅
# 3         MS100作为SE主机、DP120E虚拟分控，性价比高    ✅    ✅   ✅虚     ✅      ✅      ✅
# 4       MS100作为SE主机、DP120分控，稳定安全，豪华配置    ✅    ✅   ✅硬     ✅      ✅      ✅
# 5                 支持定制开发、集成对接、40间+会议室    ✅    ✅   ✅硬     ✅      ✅      ✅
# 6                                 NaN  NaN  NaN  NaN   NaN    NaN    NaN
# 7                    具备一键入会功能，需配置虚拟分控    ✅    ❌   ✅虚     ❌      ✅      ✅
# 8                无一键入会功能，SE最多支持40间会议室    ✅    ❌    ❌     ❌      ❌      ✅
# 9                 支持定制开发、集成对接、40间+会议室    ✅    ❌    ❌     ❌      ❌      ✅
# 10                                NaN  NaN  NaN  NaN   NaN    NaN    NaN
# 11              MS100作为虚拟分控和SE主机，性价比高    ❌    ✅   ✅虚     ✅      ✅      ❌
# 12        MS100作为SE主机、DP120E虚拟分控，性价比高    ❌    ✅   ✅虚     ✅      ✅      ❌
# 13      MS100作为SE主机、DP120分控，稳定安全，豪华配置    ❌    ✅   ✅硬     ✅      ✅      ❌
# 14                                NaN  NaN  NaN  NaN   NaN    NaN    NaN
# 15                    分控具备基础告警、远程监控能力    ❌    ❌   ✅硬     ✅      ✅      ❌
# 16                                NaN  NaN  NaN  NaN   NaN    NaN    NaN
# 17                    大型体育场馆，采用WIFI覆盖    ❌    ❌   ✅硬     ✅      ✅      ❌
# 18                      大型体育场馆，采用5G覆盖    ❌    ❌   ✅硬     ✅      ✅      ❌
# 19                                NaN  NaN  NaN  NaN   NaN    NaN    NaN
# 20                                NaN  NaN  NaN  NaN   NaN    NaN    NaN
# 21                                NaN  NaN  NaN  NaN   NaN    NaN    NaN
# 22                     参数信息以该表为准，定期发布  NaN  NaN  NaN   NaN    NaN    NaN
# 23                            软件参数规格表  NaN  NaN  NaN   NaN    NaN    NaN
#
#    MT会议主机 MS集控主机
# 0     NaN    NaN
# 1       ✅      ❌
# 2       ✅      ✅
# 3       ✅      ✅
# 4       ✅      ✅
# 5       ✅      ✅
# 6     NaN    NaN
# 7       ✅      ✅
# 8       ❌      ✅
# 9       ❌      ✅
# 10    NaN    NaN
# 11      ✅      ✅
# 12      ✅      ✅
# 13      ✅      ✅
# 14    NaN    NaN
# 15      ✅      ❌
# 16    NaN    NaN
# 17      ❌      ❌
# 18      ❌      ❌
# 19    NaN    NaN
# 20    NaN    NaN
# 21    NaN    NaN
# 22    NaN    NaN
# 23    NaN    NaN

# %%
import xlrd
df = pd.read_csv('/mnt/d/project/zzbc/experiment_project/experiment_project/audio/data/zip/原始数据/解压后数据/product list 1.xlsx',encoding='ISO-8859-1')
df
# wb = xlrd.open_workbook('/mnt/d/project/zzbc/experiment_project/experiment_project/audio/data/zip/原始数据/解压后数据/product list 1.xlsx', encoding_override='gbk')
# 
# df = pd.read_excel(wb)
# df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[29], line 2
#       1 import xlrd
# ----> 2 df = pd.read_csv('/mnt/d/project/zzbc/experiment_project/experiment_project/audio/data/zip/原始数据/解压后数据/product list 1.xlsx',encoding='ISO-8859-1')
#       3 df
#       4 # wb = xlrd.open_workbook('/mnt/d/project/zzbc/experiment_project/experiment_project/audio/data/zip/原始数据/解压后数据/product list 1.xlsx', encoding_override='gbk')
#       5 #
#       6 # df = pd.read_excel(wb)
#       7 # df
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1778, in TextFileReader.read(self, nrows)
#    1771 nrows = validate_integer("nrows", nrows)
#    1772 try:
#    1773     # error: "ParserBase" has no attribute "read"
#    1774     (
#    1775         index,
#    1776         columns,
#    1777         col_dict,
# -> 1778     ) = self._engine.read(  # type: ignore[attr-defined]
#    1779         nrows
#    1780     )
#    1781 except Exception:
#    1782     self.close()
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     228 try:
#     229     if self.low_memory:
# --> 230         chunks = self._reader.read_low_memory(nrows)
#     231         # destructive to chunks
#     232         data = _concatenate_chunks(chunks)
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/_libs/parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/_libs/parsers.pyx:866, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/_libs/parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/pandas/_libs/parsers.pyx:1973, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2 fields in line 6, saw 5

# %%
df
# Out:
#             ????  ??                             ????.1     ??.1      ??.2  \
# 0            NaN  ??              ???????????????A??B??      NaN       NaN
# 1            NaN   A      ezCloud??????????????????????      NaN       NaN
# 2   1.100001e+09  A1                         ??????????  ezCloud      V2.0
# 3   1.100001e+09  A2                       ????????????  ezCloud      V2.0
# 4   7.000000e+09  A3                     ezCloud???????  ezCloud  SAAS0001
# 5   7.000000e+09  A4                          ?????????  ezCloud  SWL20001
# 6   7.000000e+09  A5                       ????????????  ezCloud  SWL90002
# 7   7.000000e+09  A6                             ??????       ??        ??
# 8   7.000000e+09  A7                             ??????       ??        ??
# 9            NaN   B  ezCloud SE??????40???????????????      NaN       NaN
# 10  1.100001e+09  B1                         ??????????  ezCloud      V2.0
# 11  1.100001e+09  B2                       ????????????  ezCloud      V2.0
# 12  1.100001e+09  B3                       ezCloudSE???  ezCloud  SWK-SE01
# 13           NaN   C                ezControl??????????      NaN       NaN
# 14  1.100001e+09  C1                           ????????  ezCloud      V2.0
# 15  7.000000e+09  C2                           ????????  ezCloud  SWL30001
# 16           NaN   D               ezCloud?????????????      NaN       NaN
# 17  1.100001e+09  D1                       ????????????  ezCloud      V1.0
# 18  7.000000e+09  D2                         ??????????       ??        ??
# 19  7.000000e+09  D3                             ??????       ??        ??
# 20           NaN  ??                    ???????????????      NaN
# 21           NaN   A                         ??????????      NaN       NaN
# 22  7.000000e+09  A1                         ??????????       ??        ??
# 23           NaN   B                            ???????      NaN       NaN
# 24  1.100001e+09  B1                            ???????  ezCloud      V2.0
# 25  1.100001e+09  B2                          ????SDK??  ezCloud  SWA90001
# 26  1.100001e+09  B3                          ?????????  ezCloud      V2.0
# 27           NaN   C                            ???????      NaN       NaN
# 28  1.100001e+09  C1                           ????????  ezCloud      V2.0
# 29  1.100001e+09  C2                    ???????????????  ezCloud      V2.0
# 30           NaN   D                             ??????      NaN       NaN
# 31  1.100001e+09  D1                          ?????????  ezCloud      V2.0
# 32           NaN   E                            ???????      NaN       NaN
# 33  7.000000e+09  E1                            ???????       ??  SWL90003
# 34  7.000000e+09  E2                            ???????       ??  SWL90004
#
#                   ERP??                                               ??.3  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2         SW-EZLINK-V02  ??????????????????????????????????????????????...
# 3      SW-EZMANAGER-V02  ???????????????????????????485????????????\n??...
# 4              SAAS0001                        ???????????????????????????
# 5              SWL20001                             ??????????????????1???
# 6              SWL90002                            ???????????????????????
# 7                    ??  ????????????OA????????????????????????????????...
# 8                    ??  ezCloud???????????linux?????k8s???????????????...
# 9                   NaN                                                NaN
# 10     SW-EZLINK-SE-V02  ??????????????????????????????????????????????...
# 11  SW-EZMANAGER-SE-V02  ??????????????????????????????????????????????...
# 12             SWK-SE01  ezCloud SE?????U????????SW-EZLINK-SE-V02?SW-EZ...
# 13                  NaN                                                NaN
# 14     SW-EZCONTROL-V02  ??Web?Admin???????????????????????????????????...
# 15             SWL30001                             ??????????????????1???
# 16                  NaN                                                NaN
# 17       SW-EZCLOUD-V01  ????????????????????????????????AIoT??????????...
# 18                   ??                                  ?????????????????
# 19                   ??                        ???????????????UI???3D?????
# 20                                                                     NaN
# 21                  NaN                                                NaN
# 22                   ??  DP????? ???????????\n1. ??????????????????????...
# 23                  NaN                                                NaN
# 24             SWA10002  ????????????????????????????Logo????????3?????...
# 25             SWA90001                   ??????SDK???????????????????????
# 26             SWA10004  ??????????????????????????\n??????????????????...
# 27                  NaN                                                NaN
# 28             SWA30001  ??????????????????????????????????????????????...
# 29             SWA30002  ??????????????????????????????????????????????...
# 30                  NaN                                                NaN
# 31             SWA30003  ??????????????????????????????????????\n??????...
# 32                  NaN                                                NaN
# 33             SWL90003   ??????????\n1.????10???\n2.??????10?????50??1...
# 34             SWL90004  ??????????\n1.??????2???\n2.?????10??50??100??...
#
#    ??.4  ??.5 ??.6  ...                                           ????????  \
# 0   NaN   NaN  NaN  ...                                                NaN
# 1   NaN   NaN  NaN  ...                                                NaN
# 2    ??   0.0    ?  ...      1??????????????????????ezCloud??????????????
# 3    ??   0.0    ?  ...      1??????????????????????ezCloud??????????????
# 4    ??   0.0    ?  ...                                 ?????????????DEMO?
# 5    ??   0.0    ?  ...  1?????????????\n2?????????????????????????????...
# 6    ??   0.0    ?  ...            1??????????????????????????????4?????4?
# 7    ??   0.0   ??  ...                                   1???????????????
# 8    ??   0.0    ?  ...                                  ?????????????????
# 9   NaN   NaN  NaN  ...                                                NaN
# 10   ??   0.0    ?  ...  1????????ezCloudSE??????SWK-SE01???1100000960?...
# 11   ??   0.0    ?  ...  1????????ezCloudSE??????SWK-SE01???1100000960?...
# 12   ??   0.0    ?  ...       1?SW-EZLINK-SE-V02?SW-EZMANAGER-SE-V02???1??
# 13  NaN   NaN  NaN  ...                                                NaN
# 14   ??   0.0    ?  ...  1?????IPS DP120E???????\n2????IPS MS100???????...
# 15   ??   0.0    ?  ...                                     1?????????????
# 16  NaN   NaN  NaN  ...                                                NaN
# 17   ??   0.0    ?  ...      1????????ezCloudSE??????SWK-SE01???1100000960
# 18   ??   0.0    ?  ...                            1????????SW-EZCLOUD-V01
# 19   ??   0.0   ??  ...                                       1???????????
# 20  NaN   NaN  NaN  ...                                                NaN
# 21  NaN   NaN  NaN  ...                                                NaN
# 22   ??   0.0    ?  ...  1??????????????\n2??????????????\n3????????SWA...
# 23  NaN   NaN  NaN  ...                                                NaN
# 24   ??   0.0    ?  ...               1?????IPS CTS??????\n2??IPS?????????
# 25   ??   0.0    ?  ...                                       ????????????
# 26   ??   0.0    ?  ...                                  1????????????????
# 27  NaN   NaN  NaN  ...                                                NaN
# 28   ??   0.0    ?  ...  1?10??????????\n2?????IPS CTS??????\n3??IPS???...
# 29   ??   0.0    ?  ...  1??????????????2?10??????????\n3?????IPS CTS??...
# 30  NaN   NaN  NaN  ...                                                NaN
# 31   ??   0.0    ?  ...                 1?????IPS MT?????\n2??IPS?????????
# 32  NaN   NaN  NaN  ...                                                NaN
# 33   ??   0.0    ?  ...  ?????????\n???????????10?????10??????\n???????...
# 34   ??   0.0    ?  ...                                                NaN
#
#                                                ????.2             ?????????  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                   NaN
# 2   ??????????????????????????????????????????????...  ????????????????????
# 3   ????????????????????????????485????????????\n?...  ????????????????????
# 4                                                 NaN                   NaN
# 5                                                 NaN                   NaN
# 6                                                 NaN                   NaN
# 7                                                 NaN                   NaN
# 8                                                 NaN                   NaN
# 9                                                 NaN                   NaN
# 10  ??????????????????????????????????????????????...  ????????????????????
# 11  ??????????????????????????????????????????????...  ????????????????????
# 12                                                NaN                   NaN
# 13                                                NaN                   NaN
# 14  ???Web?Admin??????????????????????????????????...  ????????????????????
# 15                                                NaN                   NaN
# 16                                                NaN                   NaN
# 17  ????????????????????????????????AIoT??????????...                   NaN
# 18                                                NaN                   NaN
# 19                                                NaN                   NaN
# 20                                                NaN                   NaN
# 21                                                NaN                   NaN
# 22                                                NaN                   NaN
# 23                                                NaN                   NaN
# 24  ????????????????????????????Logo????????3?????...  ????????????????????
# 25  ??????????????????????????\n??????????????????...                   NaN
# 26  ??????????????????????????\n ?????????????????...  ????????????????????
# 27                                                NaN                   NaN
# 28  ??????????????????????????????????????????????...  ????????????????????
# 29  ??????????????????????????????????????????????...  ????????????????????
# 30                                                NaN                   NaN
# 31  ???????????????????????????????????????\n?????...  ????????????????????
# 32                                                NaN                   NaN
# 33                                                NaN                   NaN
# 34                                                NaN                   NaN
#
#                                                ????.3  \
# 0                                                 NaN
# 1                                                 NaN
# 2   1???????OA??????????????????????????????\n2?DF...
# 3   1???????OA??????????????????????????????\n2?DF...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  1???????OA??????????????????????????????\n2?DF...
# 11  1???????OA??????????????????????????????\n2?DF...
# 12                                                NaN
# 13                                                NaN
# 14  1???????OA??????????????????????????????\n2?DF...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  1???????OA??????????????????????????????\n2?DF...
# 25                                                NaN
# 26  1???????OA??????????????????????????????\n2?DF...
# 27                                                NaN
# 28  1???????OA??????????????????????????????\n2?DF...
# 29  1???????OA??????????????????????????????\n2?DF...
# 30                                                NaN
# 31  1???????OA??????????????????????????????\n2?DF...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                                          ????????????  \
# 0                                                 NaN
# 1                                                 NaN
# 2   ????????????ISO9001????????\n?????????????????...
# 3   ????????????ISO9001????????\n?????????????????...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  ????????????ISO9001????????\n?????????????????...
# 11  ????????????ISO9001????????\n?????????????????...
# 12                                                NaN
# 13                                                NaN
# 14  ????????????ISO9001????????\n?????????????????...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  ????????????ISO9001????????\n?????????????????...
# 25                                                NaN
# 26  ????????????ISO9001????????\n?????????????????...
# 27                                                NaN
# 28  ????????????ISO9001????????\n?????????????????...
# 29  ????????????ISO9001????????\n?????????????????...
# 30                                                NaN
# 31  ????????????ISO9001????????\n?????????????????...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                                                  ??.9  \
# 0                                                 NaN
# 1                                                 NaN
# 2   1?????\n2?????\n3?????\n4?????\n5?????\n6?????...
# 3   1?????\n2?????\n3?????\n4?????\n5?????\n6?????...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  1?????\n2?????\n3?????\n4?????\n5?????\n6?????...
# 11  1?????\n2?????\n3?????\n4?????\n5?????\n6?????...
# 12                                                NaN
# 13                                                NaN
# 14  1?????\n2?????\n3?????\n4?????\n5?????\n6?????...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  1?????\n2?????\n3?????\n4?????\n5?????\n6?????...
# 25                                                NaN
# 26  1?????\n2?????\n3?????\n4?????\n5?????\n6?????...
# 27                                                NaN
# 28  1?????\n2?????\n3?????\n4?????\n5?????\n6?????...
# 29  1?????\n2?????\n3?????\n4?????\n5?????\n6?????...
# 30                                                NaN
# 31  1?????\n2?????\n3?????\n4?????\n5?????\n6?????...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                                     ????.4  \
# 0                                      NaN
# 1                                      NaN
# 2   ???????AMX?Extron\n?????????????DFoucs
# 3   ???????AMX?Extron\n?????????????DFoucs
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10  ???????AMX?Extron\n?????????????DFoucs
# 11  ???????AMX?Extron\n?????????????DFoucs
# 12                                     NaN
# 13                                     NaN
# 14  ???????AMX?Extron\n?????????????DFoucs
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24  ???????AMX?Extron\n?????????????DFoucs
# 25  ???????AMX?Extron\n?????????????DFoucs
# 26  ???????AMX?Extron\n?????????????DFoucs
# 27                                     NaN
# 28  ???????AMX?Extron\n?????????????DFoucs
# 29  ???????AMX?Extron\n?????????????DFoucs
# 30                                     NaN
# 31  ???????AMX?Extron\n?????????????DFoucs
# 32                                     NaN
# 33                                     NaN
# 34                                     NaN
#
#                                           ?????????.1  \
# 0                                                 NaN
# 1                                                 NaN
# 2   ?10972334? ??????????V2.0\n?4612640? ?????????...
# 3   ?10972346? ????????????V2.0\n?4592791? ???????...
# 4                                                   /
# 5                                                   /
# 6                                                   /
# 7                                                   /
# 8                                                   /
# 9                                                 NaN
# 10  ?10972334? ??????????V2.0\n?4612640? ?????????...
# 11  ?10972346? ????????????V2.0\n?4592791? ???????...
# 12                                                NaN
# 13                                                NaN
# 14  ?11010758? ????????V2.0\n?4635879? ??ARM??????...
# 15                                                  /
# 16                                                NaN
# 17                        ?10644753? ????????????V1.0
# 18                                                  /
# 19                                                  /
# 20                                                NaN
# 21                                                NaN
# 22                                                  /
# 23                                                NaN
# 24    ?11010846? ???????V2.0\n?6693114? ?????????V1.0
# 25                                                  /
# 26                           ?11010805? ?????????V2.0
# 27                                                NaN
# 28  ?11010717? ????????V2.0\n?6059993? ???????????...
# 29  ?11010717? ????????V2.0\n?6059993? ???????????...
# 30                                                NaN
# 31                           ?11010847? ?????????V2.0
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                           ????.5 ???????
# 0                            NaN     NaN
# 1                            NaN     NaN
# 2   ezCloud???????v20220514.pdf        1
# 3   ezCloud???????v20220514.pdf        1
# 4                            NaN       1
# 5                            NaN       1
# 6                            NaN       1
# 7                            NaN    ????
# 8                            NaN       1
# 9                            NaN     NaN
# 10      ezCloud SE??v202303.pdf        1
# 11      ezCloud SE??v202303.pdf        1
# 12                           NaN       1
# 13                           NaN     NaN
# 14                           NaN       1
# 15                           NaN       1
# 16                           NaN     NaN
# 17                           NaN       1
# 18                           NaN       1
# 19                           NaN    ????
# 20                           NaN     NaN
# 21                           NaN     NaN
# 22                           NaN       1
# 23                           NaN     NaN
# 24                           NaN       1
# 25                           NaN       1
# 26                           NaN       1
# 27                           NaN     NaN
# 28                           NaN       1
# 29                           NaN       1
# 30                           NaN     NaN
# 31                           NaN       1
# 32                           NaN     NaN
# 33                           NaN       1
# 34                           NaN       1
#
# [35 rows x 22 columns]

# %%
# Generate the Cypher statement

print(cypher_statement)
# Out:
# MERGE (f:SourceFile {name: 'ez_cloud'})
#     MERGE (s:SourceSheet {name: 'SE预约_集控_虚拟分控_40间_'})
#     MERGE (s)-[:BELONGS_TO]->(f)
#
#             MERGE (t_0:设备名称 {name: '集控室'})
#             MERGE (t_0)-[:设备名称]->(s)
#
#                     MERGE (p_0_序号:序号 {value: '一、'})
#                     MERGE (t_0)-[:序号]->(p_0_序号)
#
#                     MERGE (p_0_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_0)-[:模板名称]->(p_0_模板名称)
#
#                     MERGE (p_0_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_0)-[:source_file]->(p_0_source_file)
#
#                     MERGE (p_0_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_0)-[:source_sheet]->(p_0_source_sheet)
#
#             MERGE (t_1:设备名称 {name: '软件'})
#             MERGE (t_1)-[:设备名称]->(s)
#
#                     MERGE (p_1_序号:序号 {value: 'A'})
#                     MERGE (t_1)-[:序号]->(p_1_序号)
#
#                     MERGE (p_1_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_1)-[:模板名称]->(p_1_模板名称)
#
#                     MERGE (p_1_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_1)-[:source_file]->(p_1_source_file)
#
#                     MERGE (p_1_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_1)-[:source_sheet]->(p_1_source_sheet)
#
#             MERGE (t_2:设备名称 {name: '智慧会议预约管理系统'})
#             MERGE (t_2)-[:设备名称]->(s)
#
#                     MERGE (p_2_物料编码:物料编码 {value: '1100000753.0'})
#                     MERGE (t_2)-[:物料编码]->(p_2_物料编码)
#
#                     MERGE (p_2_序号:序号 {value: 'B1'})
#                     MERGE (t_2)-[:序号]->(p_2_序号)
#
#                     MERGE (p_2_品牌:品牌 {value: 'ezCloud'})
#                     MERGE (t_2)-[:品牌]->(p_2_品牌)
#
#                     MERGE (p_2_型号:型号 {value: 'V2.0'})
#                     MERGE (t_2)-[:型号]->(p_2_型号)
#
#                     MERGE (p_2_ERP型号:ERP型号 {value: 'SW-EZLINK-SE-V02'})
#                     MERGE (t_2)-[:ERP型号]->(p_2_ERP型号)
#
#                     MERGE (p_2_规格:规格 {value: '功能每月更新，请以最终【参数表】规格为准'})
#                     MERGE (t_2)-[:规格]->(p_2_规格)
#
#                     MERGE (p_2_产地:产地 {value: '中国'})
#                     MERGE (t_2)-[:产地]->(p_2_产地)
#
#                     MERGE (p_2_数量:数量 {value: '1.0'})
#                     MERGE (t_2)-[:数量]->(p_2_数量)
#
#                     MERGE (p_2_单位:单位 {value: '套'})
#                     MERGE (t_2)-[:单位]->(p_2_单位)
#
#                     MERGE (p_2_备注_注意事项_:备注_注意事项_ {value: '1、名称与ezCloud一致，只是型号不同'})
#                     MERGE (t_2)-[:备注_注意事项_]->(p_2_备注_注意事项_)
#
#                     MERGE (p_2_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_2)-[:模板名称]->(p_2_模板名称)
#
#                     MERGE (p_2_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_2)-[:source_file]->(p_2_source_file)
#
#                     MERGE (p_2_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_2)-[:source_sheet]->(p_2_source_sheet)
#
#             MERGE (t_3:设备名称 {name: '智慧会议集中控制管理系统'})
#             MERGE (t_3)-[:设备名称]->(s)
#
#                     MERGE (p_3_物料编码:物料编码 {value: '1100000754.0'})
#                     MERGE (t_3)-[:物料编码]->(p_3_物料编码)
#
#                     MERGE (p_3_序号:序号 {value: 'B2'})
#                     MERGE (t_3)-[:序号]->(p_3_序号)
#
#                     MERGE (p_3_品牌:品牌 {value: 'ezCloud'})
#                     MERGE (t_3)-[:品牌]->(p_3_品牌)
#
#                     MERGE (p_3_型号:型号 {value: 'V2.0'})
#                     MERGE (t_3)-[:型号]->(p_3_型号)
#
#                     MERGE (p_3_ERP型号:ERP型号 {value: 'SW-EZMANAGER-SE-V02'})
#                     MERGE (t_3)-[:ERP型号]->(p_3_ERP型号)
#
#                     MERGE (p_3_规格:规格 {value: '功能每月更新，请以最终【参数表】规格为准'})
#                     MERGE (t_3)-[:规格]->(p_3_规格)
#
#                     MERGE (p_3_产地:产地 {value: '中国'})
#                     MERGE (t_3)-[:产地]->(p_3_产地)
#
#                     MERGE (p_3_数量:数量 {value: '1.0'})
#                     MERGE (t_3)-[:数量]->(p_3_数量)
#
#                     MERGE (p_3_单位:单位 {value: '套'})
#                     MERGE (t_3)-[:单位]->(p_3_单位)
#
#                     MERGE (p_3_备注_注意事项_:备注_注意事项_ {value: '1、名称与ezCloud一致，只是型号不同'})
#                     MERGE (t_3)-[:备注_注意事项_]->(p_3_备注_注意事项_)
#
#                     MERGE (p_3_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_3)-[:模板名称]->(p_3_模板名称)
#
#                     MERGE (p_3_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_3)-[:source_file]->(p_3_source_file)
#
#                     MERGE (p_3_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_3)-[:source_sheet]->(p_3_source_sheet)
#
#             MERGE (t_4:设备名称 {name: '智能物联控制系统'})
#             MERGE (t_4)-[:设备名称]->(s)
#
#                     MERGE (p_4_物料编码:物料编码 {value: '1100000745.0'})
#                     MERGE (t_4)-[:物料编码]->(p_4_物料编码)
#
#                     MERGE (p_4_序号:序号 {value: 'C1'})
#                     MERGE (t_4)-[:序号]->(p_4_序号)
#
#                     MERGE (p_4_品牌:品牌 {value: 'ezCloud'})
#                     MERGE (t_4)-[:品牌]->(p_4_品牌)
#
#                     MERGE (p_4_型号:型号 {value: 'V2.0'})
#                     MERGE (t_4)-[:型号]->(p_4_型号)
#
#                     MERGE (p_4_ERP型号:ERP型号 {value: 'SW-EZCONTROL-V02'})
#                     MERGE (t_4)-[:ERP型号]->(p_4_ERP型号)
#
#                     MERGE (p_4_规格:规格 {value: '内置40个虚拟分控房间授权。功能每月更新，请以最终【参数表】规格为准'})
#                     MERGE (t_4)-[:规格]->(p_4_规格)
#
#                     MERGE (p_4_产地:产地 {value: '中国'})
#                     MERGE (t_4)-[:产地]->(p_4_产地)
#
#                     MERGE (p_4_数量:数量 {value: '1.0'})
#                     MERGE (t_4)-[:数量]->(p_4_数量)
#
#                     MERGE (p_4_单位:单位 {value: '套'})
#                     MERGE (t_4)-[:单位]->(p_4_单位)
#
#                     MERGE (p_4_备注_注意事项_:备注_注意事项_ {value: '配合IPS MS100集控主机使用；
# 需要配中控的房间才算房间数；'})
#                     MERGE (t_4)-[:备注_注意事项_]->(p_4_备注_注意事项_)
#
#                     MERGE (p_4_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_4)-[:模板名称]->(p_4_模板名称)
#
#                     MERGE (p_4_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_4)-[:source_file]->(p_4_source_file)
#
#                     MERGE (p_4_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_4)-[:source_sheet]->(p_4_source_sheet)
#
#             MERGE (t_5:设备名称 {name: '硬件'})
#             MERGE (t_5)-[:设备名称]->(s)
#
#                     MERGE (p_5_序号:序号 {value: 'B'})
#                     MERGE (t_5)-[:序号]->(p_5_序号)
#
#                     MERGE (p_5_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_5)-[:模板名称]->(p_5_模板名称)
#
#                     MERGE (p_5_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_5)-[:source_file]->(p_5_source_file)
#
#                     MERGE (p_5_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_5)-[:source_sheet]->(p_5_source_sheet)
#
#             MERGE (t_6:设备名称 {name: '会议集控专用服务主机'})
#             MERGE (t_6)-[:设备名称]->(s)
#
#                     MERGE (p_6_物料编码:物料编码 {value: '1100000744.0'})
#                     MERGE (t_6)-[:物料编码]->(p_6_物料编码)
#
#                     MERGE (p_6_序号:序号 {value: 'B1'})
#                     MERGE (t_6)-[:序号]->(p_6_序号)
#
#                     MERGE (p_6_品牌:品牌 {value: 'IPS'})
#                     MERGE (t_6)-[:品牌]->(p_6_品牌)
#
#                     MERGE (p_6_型号:型号 {value: 'MS100'})
#                     MERGE (t_6)-[:型号]->(p_6_型号)
#
#                     MERGE (p_6_ERP型号:ERP型号 {value: 'MS100'})
#                     MERGE (t_6)-[:ERP型号]->(p_6_ERP型号)
#
#                     MERGE (p_6_规格:规格 {value: '硬件参数：
# 1U机架式服务器，采用x86平台架构
# i5 处理器，6核12线程，主频2.9GHz
# 16G（8G DDR4*2）内存，最大可扩展至64G
# 128G SSD/1TB SATA 7200RPM企业级硬盘
# 1U300W电源
# 1U2盘位
# 2个LAN接口，100/1000M自适应
# 4个USB3.0接口
# 4个USB2.0接口
# 开关键保护装置，防止误触碰电源键
#
# 功能参数：
# 完全兼容ezCloud系统，包含设备管理、会议室管理、会议管理、设备联检、巡检、告警、远程控制等
# 采用全国产欧拉操作系统，满足信创要求，同时兼容麒麟、UOS统信、中科等国产操作系统'})
#                     MERGE (t_6)-[:规格]->(p_6_规格)
#
#                     MERGE (p_6_产地:产地 {value: '中国'})
#                     MERGE (t_6)-[:产地]->(p_6_产地)
#
#                     MERGE (p_6_数量:数量 {value: '1.0'})
#                     MERGE (t_6)-[:数量]->(p_6_数量)
#
#                     MERGE (p_6_单位:单位 {value: '台'})
#                     MERGE (t_6)-[:单位]->(p_6_单位)
#
#                     MERGE (p_6_备注_注意事项_:备注_注意事项_ {value: '【单机支持50间会议室，如内置虚拟分控，则仅支持20间会议室】'})
#                     MERGE (t_6)-[:备注_注意事项_]->(p_6_备注_注意事项_)
#
#                     MERGE (p_6_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_6)-[:模板名称]->(p_6_模板名称)
#
#                     MERGE (p_6_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_6)-[:source_file]->(p_6_source_file)
#
#                     MERGE (p_6_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_6)-[:source_sheet]->(p_6_source_sheet)
#
#             MERGE (t_7:设备名称 {name: '虚拟智能分布式控制器'})
#             MERGE (t_7)-[:设备名称]->(s)
#
#                     MERGE (p_7_物料编码:物料编码 {value: '1100000679.0'})
#                     MERGE (t_7)-[:物料编码]->(p_7_物料编码)
#
#                     MERGE (p_7_序号:序号 {value: 'A2'})
#                     MERGE (t_7)-[:序号]->(p_7_序号)
#
#                     MERGE (p_7_品牌:品牌 {value: 'IPS'})
#                     MERGE (t_7)-[:品牌]->(p_7_品牌)
#
#                     MERGE (p_7_型号:型号 {value: 'DP120E'})
#                     MERGE (t_7)-[:型号]->(p_7_型号)
#
#                     MERGE (p_7_ERP型号:ERP型号 {value: 'DP120E'})
#                     MERGE (t_7)-[:ERP型号]->(p_7_ERP型号)
#
#                     MERGE (p_7_规格:规格 {value: '硬件参数：
# 采用x86平台架构
# i5 处理器，6核12线程，主频2.9GHz
# 16G（8G DDR4*2）内存，最大可扩展至64G
# 128G SSD/1TB SATA 7200RPM企业级硬盘
# 1U300W电源
# 1U2盘位
# 2个RJ45 LAN接口，100/1000M自适应
# 4个USB3.0接口
# 4个USB2.0接口
# 开关键保护装置，防止误触碰电源键
#
# 功能参数：
# 独家可配置式的编程架构，独创ezcontrol监控总线，实现对接设备零编码功能配置
# 采用虚拟化技术，灵活扩展房间和设备数量，单机可支持50个房间、300个设备的控制和监测；
# 采用B/S架构设计，基于Web的管理控制界面，无需安装任何调试客户端即可对设备进行配置；
# 基于Web的Admin管理控制界面，采用图形化的设备配置，标准实施零编程，定制需求低代码实现；
# 支持组合命令，以图形化方式将多设备、多控制指令组合成单一控制指令；
# 支持规则引擎，图形化方式将设备和房间状态与控制进行逻辑设置，实现如会前自动入会、会后自动恢复设备设置；
# 支持设备状态采集，可自定义采集周期，并将设备原始协议转化成语义化状态；
# 支持MQTT协议上报设备状态信息，与集控系统对接，可远程通过网页进行设备控制和监控设备状态，如音频处理器电平、通道静音、投影仪信号源、会议白板信号源、视频矩阵路由、视频会议电脑内存及CPU资源状态等；
# 支持在控制屏上动态告警，如音频处理器、视频矩阵、摄像头、会议白板、远程视频会议等状态异常告警、设备离线告警、视频会议电脑及CPU资源过高告警等；
# 支持多控制屏同步操作和界面切换；
# 支持设备固件远程升级；
# 支持Modbus RTU/TCP协议；
# 支持HTTP/HTTPS协议；
# 支持TCP/UDP/串口自定义协议；
# 支持TLS，SSL，SSH和SFTP网络安全协议；
# 支持IPv4、IPv6协议；
# 支持iPhone®，iPad®和Android™应用程序的控制；
# 可连接各种尺寸的控制屏，如4寸墙面屏、10寸墙面/桌面屏等；
# 高可靠性，支持7*24小时运行；'})
#                     MERGE (t_7)-[:规格]->(p_7_规格)
#
#                     MERGE (p_7_产地:产地 {value: '中国'})
#                     MERGE (t_7)-[:产地]->(p_7_产地)
#
#                     MERGE (p_7_数量:数量 {value: '1.0'})
#                     MERGE (t_7)-[:数量]->(p_7_数量)
#
#                     MERGE (p_7_单位:单位 {value: '台'})
#                     MERGE (t_7)-[:单位]->(p_7_单位)
#
#                     MERGE (p_7_备注_注意事项_:备注_注意事项_ {value: '【对应如快思聪虚拟中控，需甲方/合作方具备较好网络能力，房间多具有很高性价比】
# 1、5间大会议室以上具有性价比，10间省30%，40间省50%；
# 1、无232/485串口，如有串口设备，需配【有人N668串转网8口】；
# 2、小于5间会议室不建议配DP120E，建议配DP120；'})
#                     MERGE (t_7)-[:备注_注意事项_]->(p_7_备注_注意事项_)
#
#                     MERGE (p_7_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_7)-[:模板名称]->(p_7_模板名称)
#
#                     MERGE (p_7_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_7)-[:source_file]->(p_7_source_file)
#
#                     MERGE (p_7_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_7)-[:source_sheet]->(p_7_source_sheet)
#
#             MERGE (t_8:设备名称 {name: '网络及辅材'})
#             MERGE (t_8)-[:设备名称]->(s)
#
#                     MERGE (p_8_序号:序号 {value: 'C'})
#                     MERGE (t_8)-[:序号]->(p_8_序号)
#
#                     MERGE (p_8_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_8)-[:模板名称]->(p_8_模板名称)
#
#                     MERGE (p_8_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_8)-[:source_file]->(p_8_source_file)
#
#                     MERGE (p_8_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_8)-[:source_sheet]->(p_8_source_sheet)
#
#             MERGE (t_9:设备名称 {name: '网络交换机'})
#             MERGE (t_9)-[:设备名称]->(s)
#
#                     MERGE (p_9_序号:序号 {value: 'C1'})
#                     MERGE (t_9)-[:序号]->(p_9_序号)
#
#                     MERGE (p_9_品牌:品牌 {value: 'HUAWEI'})
#                     MERGE (t_9)-[:品牌]->(p_9_品牌)
#
#                     MERGE (p_9_型号:型号 {value: 'S5720-28P-PWR-LI-AC'})
#                     MERGE (t_9)-[:型号]->(p_9_型号)
#
#                     MERGE (p_9_ERP型号:ERP型号 {value: 'S5720-28P-PWR-LI-AC'})
#                     MERGE (t_9)-[:ERP型号]->(p_9_ERP型号)
#
#                     MERGE (p_9_规格:规格 {value: '产品类型 :POE交换机
# 24口千兆以太网交换机，4个千兆光口
# 传输速率 :10/100/1000Mbps
# 背板带宽 :336Gbps/3.024Tbps
# 包转发率 :51Mbps/126Mbps'})
#                     MERGE (t_9)-[:规格]->(p_9_规格)
#
#                     MERGE (p_9_产地:产地 {value: '中国'})
#                     MERGE (t_9)-[:产地]->(p_9_产地)
#
#                     MERGE (p_9_数量:数量 {value: '1.0'})
#                     MERGE (t_9)-[:数量]->(p_9_数量)
#
#                     MERGE (p_9_单位:单位 {value: '台'})
#                     MERGE (t_9)-[:单位]->(p_9_单位)
#
#                     MERGE (p_9_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_9)-[:模板名称]->(p_9_模板名称)
#
#                     MERGE (p_9_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_9)-[:source_file]->(p_9_source_file)
#
#                     MERGE (p_9_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_9)-[:source_sheet]->(p_9_source_sheet)
#
#             MERGE (t_10:设备名称 {name: '会议室'})
#             MERGE (t_10)-[:设备名称]->(s)
#
#                     MERGE (p_10_序号:序号 {value: '二、'})
#                     MERGE (t_10)-[:序号]->(p_10_序号)
#
#                     MERGE (p_10_ERP型号:ERP型号 {value: '    '})
#                     MERGE (t_10)-[:ERP型号]->(p_10_ERP型号)
#
#                     MERGE (p_10_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_10)-[:模板名称]->(p_10_模板名称)
#
#                     MERGE (p_10_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_10)-[:source_file]->(p_10_source_file)
#
#                     MERGE (p_10_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_10)-[:source_sheet]->(p_10_source_sheet)
#
#             MERGE (t_11:设备名称 {name: '控制部分'})
#             MERGE (t_11)-[:设备名称]->(s)
#
#                     MERGE (p_11_序号:序号 {value: 'A'})
#                     MERGE (t_11)-[:序号]->(p_11_序号)
#
#                     MERGE (p_11_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_11)-[:模板名称]->(p_11_模板名称)
#
#                     MERGE (p_11_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_11)-[:source_file]->(p_11_source_file)
#
#                     MERGE (p_11_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_11)-[:source_sheet]->(p_11_source_sheet)
#
#             MERGE (t_12:设备名称 {name: '4寸墙面智慧语音触摸控制屏'})
#             MERGE (t_12)-[:设备名称]->(s)
#
#                     MERGE (p_12_物料编码:物料编码 {value: '1100000548.0'})
#                     MERGE (t_12)-[:物料编码]->(p_12_物料编码)
#
#                     MERGE (p_12_序号:序号 {value: '1'})
#                     MERGE (t_12)-[:序号]->(p_12_序号)
#
#                     MERGE (p_12_品牌:品牌 {value: 'IPS'})
#                     MERGE (t_12)-[:品牌]->(p_12_品牌)
#
#                     MERGE (p_12_型号:型号 {value: 'CTS-401NVW'})
#                     MERGE (t_12)-[:型号]->(p_12_型号)
#
#                     MERGE (p_12_ERP型号:ERP型号 {value: 'CTS-401NVW'})
#                     MERGE (t_12)-[:ERP型号]->(p_12_ERP型号)
#
#                     MERGE (p_12_规格:规格 {value: '硬件参数：
# 系统版本：Android 7
# CPU：4核高性能处理器
# SDRAM：2GB
# FLASH：8GB
# WIFI：2.4G 802.11b/g/n
# 蓝牙：4.2
# 继电器口；3路
# MIC：2麦，3-5米拾音距离
# 屏幕：4英寸，分辨率480*480
# RJ45：1个以太网口，10M/100M/1000M 自适应
# Zigbee：802.15.4 PHY/MAC Zigbee网络协议栈
# RS485：半双工，3.81MM接口端子
# 喇叭功放：1*1W
# 输入电压：100~240VAC，50/60Hz
# 无线协议：Wi-Fi，Bluetooth，Zigbee
# 安装：86盒固定安装
#
#
# 功能参数：
# 语音识别：支持定制语音识别指令
# 唤醒词：自定义唤醒词
# 支持一键开启所有设备
# AI 语音交互、直面唤醒、智能家居控制、情景模式、Zigbee 网关功能；
# 可以轻松实现对灯光、窗帘、空调等智能设备的精准控制，无需动手，语音可控；
# 自定义联动场景，轻触面板或语音唤醒，可快速切换场景模式；
# 支持ezcontrol监控总线，实现零编码功能配置'})
#                     MERGE (t_12)-[:规格]->(p_12_规格)
#
#                     MERGE (p_12_产地:产地 {value: '中国'})
#                     MERGE (t_12)-[:产地]->(p_12_产地)
#
#                     MERGE (p_12_数量:数量 {value: '40.0'})
#                     MERGE (t_12)-[:数量]->(p_12_数量)
#
#                     MERGE (p_12_单位:单位 {value: '台'})
#                     MERGE (t_12)-[:单位]->(p_12_单位)
#
#                     MERGE (p_12_备注_注意事项_:备注_注意事项_ {value: '【放置门口快捷控制、一键入会，适合各类会议室】
# 需配置86底盒，强供电，网线
# 1、设备为220v供电，需预留强电；
# 2、可控制最多2组灯光回路或作为会议室内的门禁开关
# 3、语音唤醒词可自定义，但需要增加定制费用
# 4、语音控制需要增加定制费用'})
#                     MERGE (t_12)-[:备注_注意事项_]->(p_12_备注_注意事项_)
#
#                     MERGE (p_12_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_12)-[:模板名称]->(p_12_模板名称)
#
#                     MERGE (p_12_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_12)-[:source_file]->(p_12_source_file)
#
#                     MERGE (p_12_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_12)-[:source_sheet]->(p_12_source_sheet)
#
#             MERGE (t_13:设备名称 {name: '10.1寸桌面控制触摸屏'})
#             MERGE (t_13)-[:设备名称]->(s)
#
#                     MERGE (p_13_物料编码:物料编码 {value: '1100000671.0'})
#                     MERGE (t_13)-[:物料编码]->(p_13_物料编码)
#
#                     MERGE (p_13_序号:序号 {value: '2'})
#                     MERGE (t_13)-[:序号]->(p_13_序号)
#
#                     MERGE (p_13_品牌:品牌 {value: 'IPS'})
#                     MERGE (t_13)-[:品牌]->(p_13_品牌)
#
#                     MERGE (p_13_型号:型号 {value: 'CTS1050NWP'})
#                     MERGE (t_13)-[:型号]->(p_13_型号)
#
#                     MERGE (p_13_ERP型号:ERP型号 {value: 'CTS1050NWP'})
#                     MERGE (t_13)-[:ERP型号]->(p_13_ERP型号)
#
#                     MERGE (p_13_规格:规格 {value: '硬件参数：
# 系统：Android 8.1/10.0
# CPU：4核高性能处理器
# RAM：2GB
# 内存：16GB
# LED 屏：10.1英寸
# 灯条：LED灯条，可调RBG和混色
# RJ45：1个以太网口，10M/100M/1000M 自适应，带PoE供电
# USB：USB2.0
# 电源输入：DC 电源输入
# 麦克风：单麦克风
# WiFi：802.11b/g/n
# 蓝牙：4.0
# TF card：TF卡（支持最大 64GB）
# 喇叭：2*3W
#
#
# 功能参数：
# 一键开关所有设备
# LED灯条显示会议状态，也可用于会议室设备告警提示
# 支持多个云视频会议平台切换
# 支持一键入会，无需拨号即可参加云会议
# 支持一键求助功能，直接拨通运维人员电话
# 支持环境设备控制，如灯光、窗帘、空调等
# 支持音视频设备控制，如视频矩阵、音频处理器等
# 支持设备监控告警功能
# 支持ezcontrol监控总线，实现零编码功能配置'})
#                     MERGE (t_13)-[:规格]->(p_13_规格)
#
#                     MERGE (p_13_产地:产地 {value: '中国'})
#                     MERGE (t_13)-[:产地]->(p_13_产地)
#
#                     MERGE (p_13_数量:数量 {value: '40.0'})
#                     MERGE (t_13)-[:数量]->(p_13_数量)
#
#                     MERGE (p_13_单位:单位 {value: '台'})
#                     MERGE (t_13)-[:单位]->(p_13_单位)
#
#                     MERGE (p_13_备注_注意事项_:备注_注意事项_ {value: '【桌面控制，适合较大会议室】
# 需配置PoE供电，消费者若使用电源适配器充电,则应购买12V/1.5A,通过CCC认证并满足标准要求的电源适配器.
# 1、建议采用网口PoE供电，如交换机不支持或功率不足，可配置【HUWAWEI POE+电源适配器W0ACPSE14】'})
#                     MERGE (t_13)-[:备注_注意事项_]->(p_13_备注_注意事项_)
#
#                     MERGE (p_13_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_13)-[:模板名称]->(p_13_模板名称)
#
#                     MERGE (p_13_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_13)-[:source_file]->(p_13_source_file)
#
#                     MERGE (p_13_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_13)-[:source_sheet]->(p_13_source_sheet)
#
#             MERGE (t_14:设备名称 {name: '分布式控制器软件'})
#             MERGE (t_14)-[:设备名称]->(s)
#
#                     MERGE (p_14_物料编码:物料编码 {value: '1100000714.0'})
#                     MERGE (t_14)-[:物料编码]->(p_14_物料编码)
#
#                     MERGE (p_14_序号:序号 {value: '4'})
#                     MERGE (t_14)-[:序号]->(p_14_序号)
#
#                     MERGE (p_14_品牌:品牌 {value: 'ezCloud'})
#                     MERGE (t_14)-[:品牌]->(p_14_品牌)
#
#                     MERGE (p_14_型号:型号 {value: 'V2.0'})
#                     MERGE (t_14)-[:型号]->(p_14_型号)
#
#                     MERGE (p_14_ERP型号:ERP型号 {value: 'SWA30001'})
#                     MERGE (t_14)-[:ERP型号]->(p_14_ERP型号)
#
#                     MERGE (p_14_规格:规格 {value: '极简的用户控制界面设计，用户三分钟上手，具有浅色和深色模式，多种主题可供选择，适配各种使用场景；
#  支持多控制屏界面控制同步显示、设备状态同步展示；
#  支持与ezCloud预约系统对接，支持展示会议室预约信息列表，可快速查看会议室当前会议，及下一场和上一场会议；
#  支持与ezCloud预约系统信息发布模块对接，展示个人日程、设置忙闲状态、勿打扰、门铃控制、可视对讲、手动开锁等；
#  支持与ezCloud预约系统对接，支持视频会议一键入会，无需用户主动拨号，同时支持云视频会议和硬件视频会议，包括：腾讯会议、华为云会议、ZOOM（瞩目）、小鱼易连、华为硬件视频会议、思科硬件视频会议、Poly硬件视频会议；
#  支持与ezCloud集控系统工单模块对接，一键报修，快速上报会议室故障；
#  支持与ezcontrol监控总线，支持操作日志同步，记录用户的操作记录，便于故障重现和问题回溯；
#  支持安卓操作系统（android 9+）、鸿蒙操作系统；'})
#                     MERGE (t_14)-[:规格]->(p_14_规格)
#
#                     MERGE (p_14_产地:产地 {value: '中国'})
#                     MERGE (t_14)-[:产地]->(p_14_产地)
#
#                     MERGE (p_14_数量:数量 {value: '40.0'})
#                     MERGE (t_14)-[:数量]->(p_14_数量)
#
#                     MERGE (p_14_单位:单位 {value: '套'})
#                     MERGE (t_14)-[:单位]->(p_14_单位)
#
#                     MERGE (p_14_备注_注意事项_:备注_注意事项_ {value: '1、10寸及以上控制屏配置；
# 2、默认配合IPS CTS系列智慧屏；
# 3、非IPS品牌，核心价翻倍；'})
#                     MERGE (t_14)-[:备注_注意事项_]->(p_14_备注_注意事项_)
#
#                     MERGE (p_14_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_14)-[:模板名称]->(p_14_模板名称)
#
#                     MERGE (p_14_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_14)-[:source_file]->(p_14_source_file)
#
#                     MERGE (p_14_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_14)-[:source_sheet]->(p_14_source_sheet)
#
#             MERGE (t_15:设备名称 {name: '分布式控制器现场实施'})
#             MERGE (t_15)-[:设备名称]->(s)
#
#                     MERGE (p_15_物料编码:物料编码 {value: '7000000059.0'})
#                     MERGE (t_15)-[:物料编码]->(p_15_物料编码)
#
#                     MERGE (p_15_序号:序号 {value: '5'})
#                     MERGE (t_15)-[:序号]->(p_15_序号)
#
#                     MERGE (p_15_品牌:品牌 {value: '定制'})
#                     MERGE (t_15)-[:品牌]->(p_15_品牌)
#
#                     MERGE (p_15_型号:型号 {value: '定制'})
#                     MERGE (t_15)-[:型号]->(p_15_型号)
#
#                     MERGE (p_15_ERP型号:ERP型号 {value: '定制'})
#                     MERGE (t_15)-[:ERP型号]->(p_15_ERP型号)
#
#                     MERGE (p_15_规格:规格 {value: 'DP系列控制器 会议室操控界面实施服务
# 1. 根据会议室真实场景编程，定制开发会议室控制界面，如设计符合用户企业风格的界面及按钮；
# 2. 根据会议室类型梳理巡检步骤，如音频检测、视频检测、远程视频会议检测等；
# 3. 按照巡检步骤巡检会议室各项功能是否都正常；
# 4. 现场用会议室控制软件测试每个会议室设备，确保每次操作都准确无误，如开启设备、关闭设备、远程视频会议、灯光或空调控制及其它单个设备控制等等；
# 5. 现场将会议室设备添加至集控，保证集控可以准确无误地控制会议室设备以及获得状态；
# 6. 现场测试每个设备的异常告警能够触发；
# 7. 现场测试每个会议室的联检能够正常触发且测试结果要与实际相符；
# 8. 现场测试集控与会议室控制界面设备状态同步；'})
#                     MERGE (t_15)-[:规格]->(p_15_规格)
#
#                     MERGE (p_15_产地:产地 {value: '中国'})
#                     MERGE (t_15)-[:产地]->(p_15_产地)
#
#                     MERGE (p_15_数量:数量 {value: '40.0'})
#                     MERGE (t_15)-[:数量]->(p_15_数量)
#
#                     MERGE (p_15_单位:单位 {value: '套'})
#                     MERGE (t_15)-[:单位]->(p_15_单位)
#
#                     MERGE (p_15_备注_注意事项_:备注_注意事项_ {value: '1、厂家支持实施，需增加此项；
# 2、如合作伙伴交付，无需此项；
# 3、实施费可合并至SWA30001、SWA30002或SW-EZCONTROL-V02；'})
#                     MERGE (t_15)-[:备注_注意事项_]->(p_15_备注_注意事项_)
#
#                     MERGE (p_15_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_15)-[:模板名称]->(p_15_模板名称)
#
#                     MERGE (p_15_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_15)-[:source_file]->(p_15_source_file)
#
#                     MERGE (p_15_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_15)-[:source_sheet]->(p_15_source_sheet)
#
#             MERGE (t_16:设备名称 {name: '串转网服务器'})
#             MERGE (t_16)-[:设备名称]->(s)
#
#                     MERGE (p_16_序号:序号 {value: '5'})
#                     MERGE (t_16)-[:序号]->(p_16_序号)
#
#                     MERGE (p_16_品牌:品牌 {value: '有人'})
#                     MERGE (t_16)-[:品牌]->(p_16_品牌)
#
#                     MERGE (p_16_型号:型号 {value: 'N668'})
#                     MERGE (t_16)-[:型号]->(p_16_型号)
#
#                     MERGE (p_16_ERP型号:ERP型号 {value: 'N668'})
#                     MERGE (t_16)-[:ERP型号]->(p_16_ERP型号)
#
#                     MERGE (p_16_规格:规格 {value: '工业级多串口服务器8口机架式串口转网口232/422/485转以太网'})
#                     MERGE (t_16)-[:规格]->(p_16_规格)
#
#                     MERGE (p_16_产地:产地 {value: '中国'})
#                     MERGE (t_16)-[:产地]->(p_16_产地)
#
#                     MERGE (p_16_数量:数量 {value: '0.0'})
#                     MERGE (t_16)-[:数量]->(p_16_数量)
#
#                     MERGE (p_16_单位:单位 {value: '台'})
#                     MERGE (t_16)-[:单位]->(p_16_单位)
#
#                     MERGE (p_16_备注_注意事项_:备注_注意事项_ {value: '【如果串口不足，或使用虚拟分控时需配置】参考京东https://item.jd.com/14233393108.html '})
#                     MERGE (t_16)-[:备注_注意事项_]->(p_16_备注_注意事项_)
#
#                     MERGE (p_16_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_16)-[:模板名称]->(p_16_模板名称)
#
#                     MERGE (p_16_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_16)-[:source_file]->(p_16_source_file)
#
#                     MERGE (p_16_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_16)-[:source_sheet]->(p_16_source_sheet)
#
#             MERGE (t_17:设备名称 {name: '网口转换端子（公头）'})
#             MERGE (t_17)-[:设备名称]->(s)
#
#                     MERGE (p_17_序号:序号 {value: '6'})
#                     MERGE (t_17)-[:序号]->(p_17_序号)
#
#                     MERGE (p_17_品牌:品牌 {value: '纬诺希尔'})
#                     MERGE (t_17)-[:品牌]->(p_17_品牌)
#
#                     MERGE (p_17_型号:型号 {value: 'RJ45转DB9 DB15公头'})
#                     MERGE (t_17)-[:型号]->(p_17_型号)
#
#                     MERGE (p_17_ERP型号:ERP型号 {value: 'RJ45转DB9 DB15公头'})
#                     MERGE (t_17)-[:ERP型号]->(p_17_ERP型号)
#
#                     MERGE (p_17_规格:规格 {value: '网口转换器，公母头配对'})
#                     MERGE (t_17)-[:规格]->(p_17_规格)
#
#                     MERGE (p_17_产地:产地 {value: '中国'})
#                     MERGE (t_17)-[:产地]->(p_17_产地)
#
#                     MERGE (p_17_数量:数量 {value: '0.0'})
#                     MERGE (t_17)-[:数量]->(p_17_数量)
#
#                     MERGE (p_17_单位:单位 {value: '个'})
#                     MERGE (t_17)-[:单位]->(p_17_单位)
#
#                     MERGE (p_17_备注_注意事项_:备注_注意事项_ {value: '【配合N668使用，每个N668需要6个公头】参考淘宝：https://item.taobao.com/item.htm?id=627368063182&price=6.8&sourceType=item&sourceType=item&suid=1fa243e5-0e82-488f-a963-1c09a24269ac&ut_sk=1.Xud1329L75ADAD%2FXD59%2FpcqI_21646297_1662112038047.Copy.ShareGlobalNavigation_1&un=65b152b5d16e7da914ac4609adad532d&share_crt_v=1&un_site=0&spm=a2159r.13376460.0.0&sp_abtk=gray_ShareGlobalNavigation_1_code_simpleAndroid&tbSocialPopKey=shareItem&sp_tk=cWRuUDJ2VmFMMXE%3D&cpp=1&shareurl=true&short_name=h.U0JzBJV&bxsign=scdl9j-d4sOYpAQ5ynNUsCwpiMDKizc0d8Rttr410Rru25CuSqI2cuztOqfy_D73yS9U20Tp6WosfMsAoQIcu67RFb7UO_ggEJX05HRX6sVwwFEZc-I6qPAXuWsLP9l9fUg&app=chrome'})
#                     MERGE (t_17)-[:备注_注意事项_]->(p_17_备注_注意事项_)
#
#                     MERGE (p_17_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_17)-[:模板名称]->(p_17_模板名称)
#
#                     MERGE (p_17_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_17)-[:source_file]->(p_17_source_file)
#
#                     MERGE (p_17_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_17)-[:source_sheet]->(p_17_source_sheet)
#
#             MERGE (t_18:设备名称 {name: '网口转换端子（母头）'})
#             MERGE (t_18)-[:设备名称]->(s)
#
#                     MERGE (p_18_序号:序号 {value: '7'})
#                     MERGE (t_18)-[:序号]->(p_18_序号)
#
#                     MERGE (p_18_品牌:品牌 {value: '纬诺希尔'})
#                     MERGE (t_18)-[:品牌]->(p_18_品牌)
#
#                     MERGE (p_18_型号:型号 {value: 'RJ45转DB9 DB15母头'})
#                     MERGE (t_18)-[:型号]->(p_18_型号)
#
#                     MERGE (p_18_ERP型号:ERP型号 {value: 'RJ45转DB9 DB15母头'})
#                     MERGE (t_18)-[:ERP型号]->(p_18_ERP型号)
#
#                     MERGE (p_18_规格:规格 {value: '网口转换器，公母头配对'})
#                     MERGE (t_18)-[:规格]->(p_18_规格)
#
#                     MERGE (p_18_产地:产地 {value: '中国'})
#                     MERGE (t_18)-[:产地]->(p_18_产地)
#
#                     MERGE (p_18_数量:数量 {value: '0.0'})
#                     MERGE (t_18)-[:数量]->(p_18_数量)
#
#                     MERGE (p_18_单位:单位 {value: '个'})
#                     MERGE (t_18)-[:单位]->(p_18_单位)
#
#                     MERGE (p_18_备注_注意事项_:备注_注意事项_ {value: '【配合N668使用，每个N668需要3个母头】参考淘宝：https://item.taobao.com/item.htm?id=627368063182&price=6.8&sourceType=item&sourceType=item&suid=1fa243e5-0e82-488f-a963-1c09a24269ac&ut_sk=1.Xud1329L75ADAD%2FXD59%2FpcqI_21646297_1662112038047.Copy.ShareGlobalNavigation_1&un=65b152b5d16e7da914ac4609adad532d&share_crt_v=1&un_site=0&spm=a2159r.13376460.0.0&sp_abtk=gray_ShareGlobalNavigation_1_code_simpleAndroid&tbSocialPopKey=shareItem&sp_tk=cWRuUDJ2VmFMMXE%3D&cpp=1&shareurl=true&short_name=h.U0JzBJV&bxsign=scdl9j-d4sOYpAQ5ynNUsCwpiMDKizc0d8Rttr410Rru25CuSqI2cuztOqfy_D73yS9U20Tp6WosfMsAoQIcu67RFb7UO_ggEJX05HRX6sVwwFEZc-I6qPAXuWsLP9l9fUg&app=chrome'})
#                     MERGE (t_18)-[:备注_注意事项_]->(p_18_备注_注意事项_)
#
#                     MERGE (p_18_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_18)-[:模板名称]->(p_18_模板名称)
#
#                     MERGE (p_18_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_18)-[:source_file]->(p_18_source_file)
#
#                     MERGE (p_18_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_18)-[:source_sheet]->(p_18_source_sheet)
#
#             MERGE (t_19:设备名称 {name: 'RS232转红外模块'})
#             MERGE (t_19)-[:设备名称]->(s)
#
#                     MERGE (p_19_序号:序号 {value: '8'})
#                     MERGE (t_19)-[:序号]->(p_19_序号)
#
#                     MERGE (p_19_品牌:品牌 {value: '浩博'})
#                     MERGE (t_19)-[:品牌]->(p_19_品牌)
#
#                     MERGE (p_19_型号:型号 {value: 'HB_STR-RFK（存储型）'})
#                     MERGE (t_19)-[:型号]->(p_19_型号)
#
#                     MERGE (p_19_ERP型号:ERP型号 {value: 'HB_STR-RFK（存储型）'})
#                     MERGE (t_19)-[:ERP型号]->(p_19_ERP型号)
#
#                     MERGE (p_19_规格:规格 {value: '红外学习、红外编码器，可外接红外发射棒'})
#                     MERGE (t_19)-[:规格]->(p_19_规格)
#
#                     MERGE (p_19_产地:产地 {value: '中国'})
#                     MERGE (t_19)-[:产地]->(p_19_产地)
#
#                     MERGE (p_19_数量:数量 {value: '1.0'})
#                     MERGE (t_19)-[:数量]->(p_19_数量)
#
#                     MERGE (p_19_单位:单位 {value: '个'})
#                     MERGE (t_19)-[:单位]->(p_19_单位)
#
#                     MERGE (p_19_备注_注意事项_:备注_注意事项_ {value: '【如果有红外被控设备配置，一个红外设备配置一个】参考淘宝：https://item.taobao.com/item.htm?id=604041020710&scm=20140619.rec.827816722.604041020710'})
#                     MERGE (t_19)-[:备注_注意事项_]->(p_19_备注_注意事项_)
#
#                     MERGE (p_19_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_19)-[:模板名称]->(p_19_模板名称)
#
#                     MERGE (p_19_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_19)-[:source_file]->(p_19_source_file)
#
#                     MERGE (p_19_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_19)-[:source_sheet]->(p_19_source_sheet)
#
#             MERGE (t_20:设备名称 {name: '红外线发射棒'})
#             MERGE (t_20)-[:设备名称]->(s)
#
#                     MERGE (p_20_序号:序号 {value: '9'})
#                     MERGE (t_20)-[:序号]->(p_20_序号)
#
#                     MERGE (p_20_品牌:品牌 {value: '国产优质'})
#                     MERGE (t_20)-[:品牌]->(p_20_品牌)
#
#                     MERGE (p_20_型号:型号 {value: '国产优质'})
#                     MERGE (t_20)-[:型号]->(p_20_型号)
#
#                     MERGE (p_20_ERP型号:ERP型号 {value: '国产优质'})
#                     MERGE (t_20)-[:ERP型号]->(p_20_ERP型号)
#
#                     MERGE (p_20_规格:规格 {value: '用于发射红外信号，贴近被控设备的红外接收器'})
#                     MERGE (t_20)-[:规格]->(p_20_规格)
#
#                     MERGE (p_20_产地:产地 {value: '中国'})
#                     MERGE (t_20)-[:产地]->(p_20_产地)
#
#                     MERGE (p_20_数量:数量 {value: '1.0'})
#                     MERGE (t_20)-[:数量]->(p_20_数量)
#
#                     MERGE (p_20_单位:单位 {value: '个'})
#                     MERGE (t_20)-[:单位]->(p_20_单位)
#
#                     MERGE (p_20_备注_注意事项_:备注_注意事项_ {value: '【匹配RS232转红外模块，一个红外设备配置一个】参考淘宝：https://item.taobao.com/item.htm?spm=a1z09.2.0.0.115a2e8dtSHimU&id=39643880566&_u=t298td7j99eb'})
#                     MERGE (t_20)-[:备注_注意事项_]->(p_20_备注_注意事项_)
#
#                     MERGE (p_20_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_20)-[:模板名称]->(p_20_模板名称)
#
#                     MERGE (p_20_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_20)-[:source_file]->(p_20_source_file)
#
#                     MERGE (p_20_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_20)-[:source_sheet]->(p_20_source_sheet)
#
#             MERGE (t_21:设备名称 {name: 'CS传感器系列'})
#             MERGE (t_21)-[:设备名称]->(s)
#
#                     MERGE (p_21_序号:序号 {value: 'B'})
#                     MERGE (t_21)-[:序号]->(p_21_序号)
#
#                     MERGE (p_21_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_21)-[:模板名称]->(p_21_模板名称)
#
#                     MERGE (p_21_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_21)-[:source_file]->(p_21_source_file)
#
#                     MERGE (p_21_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_21)-[:source_sheet]->(p_21_source_sheet)
#
#             MERGE (t_22:设备名称 {name: '红外超声波双鉴传感器'})
#             MERGE (t_22)-[:设备名称]->(s)
#
#                     MERGE (p_22_物料编码:物料编码 {value: '1100000285.0'})
#                     MERGE (t_22)-[:物料编码]->(p_22_物料编码)
#
#                     MERGE (p_22_序号:序号 {value: '1'})
#                     MERGE (t_22)-[:序号]->(p_22_序号)
#
#                     MERGE (p_22_品牌:品牌 {value: 'IPS'})
#                     MERGE (t_22)-[:品牌]->(p_22_品牌)
#
#                     MERGE (p_22_型号:型号 {value: 'CS B-DIU08'})
#                     MERGE (t_22)-[:型号]->(p_22_型号)
#
#                     MERGE (p_22_ERP型号:ERP型号 {value: 'CS B-DIU08'})
#                     MERGE (t_22)-[:ERP型号]->(p_22_ERP型号)
#
#                     MERGE (p_22_规格:规格 {value: '硬件参数：
# 探测范围：直径2~6米
# 感应角度：120度圆锥角
# 供电电压：DC 12-24V
# 静功率消耗：0.15W（6.1mA）
# 最大消耗：0.47W（19.5mA）
# 通信端口：RS485
# 安装方式：吸顶式安装
# 产品尺寸：110mm×56mm
# 净重：150g
#
# 功能参数：
# 人体红外超声双鉴；
# 可设定：红外与超声波同时触发模式； 红外与超声任何一种触发模式；单红外模式；单超声波模式
# RS-485连接方式稳定、可靠，可与中控系统对接；
# 支持ezcontrol监控总线，实现零编码功能配置'})
#                     MERGE (t_22)-[:规格]->(p_22_规格)
#
#                     MERGE (p_22_产地:产地 {value: '中国'})
#                     MERGE (t_22)-[:产地]->(p_22_产地)
#
#                     MERGE (p_22_数量:数量 {value: '3.0'})
#                     MERGE (t_22)-[:数量]->(p_22_数量)
#
#                     MERGE (p_22_单位:单位 {value: '个'})
#                     MERGE (t_22)-[:单位]->(p_22_单位)
#
#                     MERGE (p_22_备注_注意事项_:备注_注意事项_ {value: '【智慧会议标配，人感自动开灯。大会议需要配置多个】'})
#                     MERGE (t_22)-[:备注_注意事项_]->(p_22_备注_注意事项_)
#
#                     MERGE (p_22_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_22)-[:模板名称]->(p_22_模板名称)
#
#                     MERGE (p_22_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_22)-[:source_file]->(p_22_source_file)
#
#                     MERGE (p_22_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_22)-[:source_sheet]->(p_22_source_sheet)
#
#             MERGE (t_23:设备名称 {name: '六合一传感器'})
#             MERGE (t_23)-[:设备名称]->(s)
#
#                     MERGE (p_23_物料编码:物料编码 {value: '1100000463.0'})
#                     MERGE (t_23)-[:物料编码]->(p_23_物料编码)
#
#                     MERGE (p_23_序号:序号 {value: '2'})
#                     MERGE (t_23)-[:序号]->(p_23_序号)
#
#                     MERGE (p_23_品牌:品牌 {value: 'IPS'})
#                     MERGE (t_23)-[:品牌]->(p_23_品牌)
#
#                     MERGE (p_23_型号:型号 {value: 'CS B-TMP6-SEN'})
#                     MERGE (t_23)-[:型号]->(p_23_型号)
#
#                     MERGE (p_23_ERP型号:ERP型号 {value: 'CS B-TMP6-SEN'})
#                     MERGE (t_23)-[:ERP型号]->(p_23_ERP型号)
#
#                     MERGE (p_23_规格:规格 {value: '硬件参数：
# 工作电压：DC 9~36V
# 工作电流：＜200mA
# 控制接口：RS4885
# 工作环境：工作温度0~50℃
# 工作湿度：15%RH-90％RH（无凝结）
# 预热时间：≤3分钟
# 适配器工作电流：12V/2A
# 使用寿命：5年（空气中）
# 净重：180g
#
# 功能参数：
# 六合一传感模块是一款集CO2、激光PM2.5、温度、湿度、TVOC 及甲醛于一体的综合型空气质量传感器。可对所处环境进行实时侦测
# 支持ezcontrol监控总线，实现零编码功能配置'})
#                     MERGE (t_23)-[:规格]->(p_23_规格)
#
#                     MERGE (p_23_产地:产地 {value: '中国'})
#                     MERGE (t_23)-[:产地]->(p_23_产地)
#
#                     MERGE (p_23_数量:数量 {value: '3.0'})
#                     MERGE (t_23)-[:数量]->(p_23_数量)
#
#                     MERGE (p_23_单位:单位 {value: '个'})
#                     MERGE (t_23)-[:单位]->(p_23_单位)
#
#                     MERGE (p_23_备注_注意事项_:备注_注意事项_ {value: '【智慧会议标配，可根据环境数据，自动调节空调、新风等系统】'})
#                     MERGE (t_23)-[:备注_注意事项_]->(p_23_备注_注意事项_)
#
#                     MERGE (p_23_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_23)-[:模板名称]->(p_23_模板名称)
#
#                     MERGE (p_23_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_23)-[:source_file]->(p_23_source_file)
#
#                     MERGE (p_23_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_23)-[:source_sheet]->(p_23_source_sheet)
#
#             MERGE (t_24:设备名称 {name: '光照度感应器'})
#             MERGE (t_24)-[:设备名称]->(s)
#
#                     MERGE (p_24_物料编码:物料编码 {value: '1100000462.0'})
#                     MERGE (t_24)-[:物料编码]->(p_24_物料编码)
#
#                     MERGE (p_24_序号:序号 {value: '3'})
#                     MERGE (t_24)-[:序号]->(p_24_序号)
#
#                     MERGE (p_24_品牌:品牌 {value: 'IPS'})
#                     MERGE (t_24)-[:品牌]->(p_24_品牌)
#
#                     MERGE (p_24_型号:型号 {value: 'CS B-LUM-SEN'})
#                     MERGE (t_24)-[:型号]->(p_24_型号)
#
#                     MERGE (p_24_ERP型号:ERP型号 {value: 'CS B-LUM-SEN'})
#                     MERGE (t_24)-[:ERP型号]->(p_24_ERP型号)
#
#                     MERGE (p_24_规格:规格 {value: '硬件参数：
# 供电电压：DC 24V（22V~26V）
# 输出形式：
# 电流：三线4mA~20mA
# 电压：三线0~5V、0~10V
# 最大允许误差：±7%
# 重复测试：±5%
# 温度特性：±0.5%/℃
# 观光体：带滤光片的硅蓝光伏探测器
# 波长范围测量：380nm~730nm
# 操作环境温湿度：
# 0℃~40℃、0%RH~70%RH（带液晶）
# 0℃`~70℃、0%RH~70%RH（不带液晶）
# 存储环境温湿度：
# -10℃~50℃、0%RH~80%RH（带液晶）
# -10℃~70℃、0%RH~80%RH（不带液晶）
# 大气压力：80kPa~110kPa
# 产品重量：约170克
#
# 功能参数：
# 支持ezcontrol监控总线，实现零编码功能配置'})
#                     MERGE (t_24)-[:规格]->(p_24_规格)
#
#                     MERGE (p_24_产地:产地 {value: '中国'})
#                     MERGE (t_24)-[:产地]->(p_24_产地)
#
#                     MERGE (p_24_数量:数量 {value: '0.0'})
#                     MERGE (t_24)-[:数量]->(p_24_数量)
#
#                     MERGE (p_24_单位:单位 {value: '个'})
#                     MERGE (t_24)-[:单位]->(p_24_单位)
#
#                     MERGE (p_24_备注_注意事项_:备注_注意事项_ {value: '【选配，可根据光照强度，自动调节灯的亮度】
# 1、一般与4路导轨式调光模块CS B-DIM0420一同使用；
# 2、可配合智能灯光系统使用，但需增加【分布式控制器现场实施】'})
#                     MERGE (t_24)-[:备注_注意事项_]->(p_24_备注_注意事项_)
#
#                     MERGE (p_24_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_24)-[:模板名称]->(p_24_模板名称)
#
#                     MERGE (p_24_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_24)-[:source_file]->(p_24_source_file)
#
#                     MERGE (p_24_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_24)-[:source_sheet]->(p_24_source_sheet)
#
#             MERGE (t_25:设备名称 {name: '8路大电流继电器'})
#             MERGE (t_25)-[:设备名称]->(s)
#
#                     MERGE (p_25_物料编码:物料编码 {value: '1100000361.0'})
#                     MERGE (t_25)-[:物料编码]->(p_25_物料编码)
#
#                     MERGE (p_25_序号:序号 {value: '4'})
#                     MERGE (t_25)-[:序号]->(p_25_序号)
#
#                     MERGE (p_25_品牌:品牌 {value: 'IPS'})
#                     MERGE (t_25)-[:品牌]->(p_25_品牌)
#
#                     MERGE (p_25_型号:型号 {value: 'CS B-REL0820'})
#                     MERGE (t_25)-[:型号]->(p_25_型号)
#
#                     MERGE (p_25_ERP型号:ERP型号 {value: 'CS B-REL0820'})
#                     MERGE (t_25)-[:ERP型号]->(p_25_ERP型号)
#
#                     MERGE (p_25_规格:规格 {value: '硬件参数：
# 输入电源：110V ~ 230V 50/60Hz
# 输出通道数：8路
# 输出接口：8 x 3位干节点
# 通道负载输出：单通道最大输出负载20A，整机设备最大输出负载：60A
# 开关器件：继电器30A/250V AC
# 控制输入：1 x RS232串口控制口母头（2-TX 3-RX 5-GND）；1 x RS232串口级联口公头（2-RX 3-TX 5-GND）
# 使用控制界面：1 x 开关按键；8 x 通道输出单独控制按键；2 x 数码ID号；1 x 电源状态LED指示灯；8 x 通道状态LED指示灯
# 温度范围：－10℃ 至 +40℃
# 湿度范围：0 至 90% RH
# 尺寸（W×D×H）：430 x 60 x 200mm
# 净重：2.5kg
#
# 功能参数：
# 采用密封防鼠式设计，可置于机柜内任意位置；
# 全新数字化设计；
# 8路通道开关状态可由面板显示；
# 通过面板一键开关，可时序关启通道，实现时序功能。
# 可通过软件方式，锁闭和解锁面板按键；
# 提供RS232输入接口，可连接电脑和中控系统
# 提供级联功能，一个中控串口可控制多达16个继电器；
# 提供端口互锁功能，可用于控制投影机电动幕，升降架，以及电动窗帘；
# 支持ezcontrol监控总线，实现零编码功能配置'})
#                     MERGE (t_25)-[:规格]->(p_25_规格)
#
#                     MERGE (p_25_产地:产地 {value: '中国'})
#                     MERGE (t_25)-[:产地]->(p_25_产地)
#
#                     MERGE (p_25_数量:数量 {value: '0.0'})
#                     MERGE (t_25)-[:数量]->(p_25_数量)
#
#                     MERGE (p_25_单位:单位 {value: '个'})
#                     MERGE (t_25)-[:单位]->(p_25_单位)
#
#                     MERGE (p_25_备注_注意事项_:备注_注意事项_ {value: '【选配，一般配合控制灯光回路、窗帘电机等设备】'})
#                     MERGE (t_25)-[:备注_注意事项_]->(p_25_备注_注意事项_)
#
#                     MERGE (p_25_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_25)-[:模板名称]->(p_25_模板名称)
#
#                     MERGE (p_25_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_25)-[:source_file]->(p_25_source_file)
#
#                     MERGE (p_25_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_25)-[:source_sheet]->(p_25_source_sheet)
#
#             MERGE (t_26:设备名称 {name: '6路24伏导轨式系统电源'})
#             MERGE (t_26)-[:设备名称]->(s)
#
#                     MERGE (p_26_物料编码:物料编码 {value: '1100000286.0'})
#                     MERGE (t_26)-[:物料编码]->(p_26_物料编码)
#
#                     MERGE (p_26_序号:序号 {value: '5'})
#                     MERGE (t_26)-[:序号]->(p_26_序号)
#
#                     MERGE (p_26_品牌:品牌 {value: 'IPS'})
#                     MERGE (t_26)-[:品牌]->(p_26_品牌)
#
#                     MERGE (p_26_型号:型号 {value: 'CS B-PWR24DC-DIN'})
#                     MERGE (t_26)-[:型号]->(p_26_型号)
#
#                     MERGE (p_26_ERP型号:ERP型号 {value: 'CS B-PWR24DC-DIN'})
#                     MERGE (t_26)-[:ERP型号]->(p_26_ERP型号)
#
#                     MERGE (p_26_规格:规格 {value: '硬件参数：
# 输入电压：AC 100V-240V
# 输入频率：50-60Hz
# 输出电压：DC 24V
# 输出电流：1.5A
# 输出容差 ±1%
# 输出噪声与纹波：120mV
# 效率：81%
# 绝缘标准：I/P-O/P：3kV/min
# 绝缘阻抗：I/P-O/P：100M Ohms/500VDC/25℃/70%RH
# 工作环境：-20~60℃，20%~90%RH
# 存储环境：-40~85℃，10%~95%RH
# 输出路数：6路
#
# 功能参数：
# LED通电指示；
# 符合DIN EN 50022标准导轨安装，安装拆卸方便；
# 可用并联方式，增加输出功率；
# 高可靠，紧凑型设计；
# 高强度弹性热朔外壳，强抗冲击，可回收，强阻燃性；
# 过载/过压/过热/短路保护 ；'})
# ...
#
#                     MERGE (p_35_规格:规格 {value: '支持会议室预约信息展示，信息包含会议室名称、房间号、企业Logo、日期时间、最近3天的预约信息、企业文化图片和宣传视频等，支持会务人员临时发布会议信息和日程；
#  支持以不可见的形式展示涉密会议，用户只能看到某时段****会议，无法查看会议详情；
#  支持当前会议状态和会议室占用状态展示，如：空闲、会议中、违规占用等，能够与空间占用感应器（如：红外超声波双鉴传感器）联动，显示会议室内有人、无人状态，并通过屏幕颜色区分会议状态；
#  支持展示领导办公室相关信息，包括办公室名称、房号、企业Logo、日期时间、领导个人忙、闲、勿打扰状态；
#  支持会议室内座位排座和签到状态显示，用户签到后，高亮闪烁提示用户就坐方位，支持多人同时提示；
#  支持多种签到方式，包括：二维码扫码签到、多人人脸签到、RFID刷卡签到；
#  支持签到二维码一码多用，空闲时扫码为会议快速预约，会议中或即将开始时为会议签到；
#  支持人脸识别本地化识别，使用中无需连接互联网，支持多人同时人脸签到（不少于4人）、戴口罩识别等，支持本地6万张人脸库，识别速度不高于1秒（光线良好，配合IPS CTS系列硬件）；
#  支持会议临时变更或取消，会议预约人、主持人或会务人员可进行操作；
#  支持会议室门锁控制，会议参会人或指定人员（如会务人员、清洁人员、运维人员等）可通过扫码、人脸识别、刷卡、密码等多种方式开锁；
#  支持会议费用即时结算，通过人脸识别或刷卡等方式确认用户身份，有结算权限的用户，将提示本次会议的费用，包括会议室预算费用、会议室实际使用费用、会务服务费等；
#  支持ezcontrol监控总线，实现零编码功能配置；
#  支持与ezCloud集控系统远程监控模块对接，支持设备状态监控、故障告警、日志上传、应用批量升级等；
#  支持夜间省电功能，定时开启、关闭系统；
#  支持应用远程静默升级；
#  支持安卓操作系统（android 7+）、鸿蒙操作系统；'})
#                     MERGE (t_35)-[:规格]->(p_35_规格)
#
#                     MERGE (p_35_产地:产地 {value: '中国'})
#                     MERGE (t_35)-[:产地]->(p_35_产地)
#
#                     MERGE (p_35_数量:数量 {value: '40.0'})
#                     MERGE (t_35)-[:数量]->(p_35_数量)
#
#                     MERGE (p_35_单位:单位 {value: '套'})
#                     MERGE (t_35)-[:单位]->(p_35_单位)
#
#                     MERGE (p_35_备注_注意事项_:备注_注意事项_ {value: '1、默认配合IPS CTS系列智慧屏；
# 2、非IPS品牌，核心价翻倍；'})
#                     MERGE (t_35)-[:备注_注意事项_]->(p_35_备注_注意事项_)
#
#                     MERGE (p_35_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_35)-[:模板名称]->(p_35_模板名称)
#
#                     MERGE (p_35_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_35)-[:source_file]->(p_35_source_file)
#
#                     MERGE (p_35_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_35)-[:source_sheet]->(p_35_source_sheet)
#
#             MERGE (t_36:设备名称 {name: '人脸识别SDK应用'})
#             MERGE (t_36)-[:设备名称]->(s)
#
#                     MERGE (p_36_物料编码:物料编码 {value: '1100000713.0'})
#                     MERGE (t_36)-[:物料编码]->(p_36_物料编码)
#
#                     MERGE (p_36_序号:序号 {value: '6'})
#                     MERGE (t_36)-[:序号]->(p_36_序号)
#
#                     MERGE (p_36_品牌:品牌 {value: 'ezCloud'})
#                     MERGE (t_36)-[:品牌]->(p_36_品牌)
#
#                     MERGE (p_36_型号:型号 {value: 'SWA90001'})
#                     MERGE (t_36)-[:型号]->(p_36_型号)
#
#                     MERGE (p_36_ERP型号:ERP型号 {value: 'SWA90001'})
#                     MERGE (t_36)-[:ERP型号]->(p_36_ERP型号)
#
#                     MERGE (p_36_规格:规格 {value: '人脸识别应用SDK授权，配合智慧会议指引屏软件，提供人脸识别功能'})
#                     MERGE (t_36)-[:规格]->(p_36_规格)
#
#                     MERGE (p_36_产地:产地 {value: '中国'})
#                     MERGE (t_36)-[:产地]->(p_36_产地)
#
#                     MERGE (p_36_数量:数量 {value: '40.0'})
#                     MERGE (t_36)-[:数量]->(p_36_数量)
#
#                     MERGE (p_36_单位:单位 {value: '套'})
#                     MERGE (t_36)-[:单位]->(p_36_单位)
#
#                     MERGE (p_36_备注_注意事项_:备注_注意事项_ {value: '【如需人脸识别功能必配】'})
#                     MERGE (t_36)-[:备注_注意事项_]->(p_36_备注_注意事项_)
#
#                     MERGE (p_36_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_36)-[:模板名称]->(p_36_模板名称)
#
#                     MERGE (p_36_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_36)-[:source_file]->(p_36_source_file)
#
#                     MERGE (p_36_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_36)-[:source_sheet]->(p_36_source_sheet)
#
#             MERGE (t_37:设备名称 {name: '云视频会议主机'})
#             MERGE (t_37)-[:设备名称]->(s)
#
#                     MERGE (p_37_序号:序号 {value: 'D'})
#                     MERGE (t_37)-[:序号]->(p_37_序号)
#
#                     MERGE (p_37_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_37)-[:模板名称]->(p_37_模板名称)
#
#                     MERGE (p_37_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_37)-[:source_file]->(p_37_source_file)
#
#                     MERGE (p_37_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_37)-[:source_sheet]->(p_37_source_sheet)
#
#             MERGE (t_38:设备名称 {name: '融合会议主机'})
#             MERGE (t_38)-[:设备名称]->(s)
#
#                     MERGE (p_38_物料编码:物料编码 {value: '1100000669.0'})
#                     MERGE (t_38)-[:物料编码]->(p_38_物料编码)
#
#                     MERGE (p_38_序号:序号 {value: '1'})
#                     MERGE (t_38)-[:序号]->(p_38_序号)
#
#                     MERGE (p_38_品牌:品牌 {value: 'IPS'})
#                     MERGE (t_38)-[:品牌]->(p_38_品牌)
#
#                     MERGE (p_38_型号:型号 {value: 'MT100'})
#                     MERGE (t_38)-[:型号]->(p_38_型号)
#
#                     MERGE (p_38_ERP型号:ERP型号 {value: 'MT100'})
#                     MERGE (t_38)-[:ERP型号]->(p_38_ERP型号)
#
#                     MERGE (p_38_规格:规格 {value: '硬件参数：
# CPU：Intel i5，四核8线程，主频2.4GHz
# 内存：8GB
# 硬盘：m.2 SSD240GB
# 网络：1G网络
# 系统：Windows 10
# HDMI IN：1×HDMI 4K @60fps输入
# HDMI OUT：4×HDMI 4K @60fps 输出 独立显示
# 扩展模块：支持WIFI、蓝牙、AP模块
# 供电：DC 12V 电源适配器
# 颜色：黑色钣金机身
# 尺寸：深168mm、宽180mm、高44.5mm
#
# 功能参数：
# 兼容华为、腾讯会议、ZOOM、CISCO、Polycomm、小鱼、亿联、钉钉多种云视频会议平台；
# 支持视频会议的一键入会、扫码入会、信息发布；
# 可监控主机CPU、内存、磁盘使用等情况，且可异常告警；
# 会议开始前，可自动开会议设备，并可联动唤醒电视（电视需支持CEC功能）
# 支持ezcontrol监控总线，实现零编码功能配置'})
#                     MERGE (t_38)-[:规格]->(p_38_规格)
#
#                     MERGE (p_38_产地:产地 {value: '中国'})
#                     MERGE (t_38)-[:产地]->(p_38_产地)
#
#                     MERGE (p_38_数量:数量 {value: '5.0'})
#                     MERGE (t_38)-[:数量]->(p_38_数量)
#
#                     MERGE (p_38_单位:单位 {value: '台'})
#                     MERGE (t_38)-[:单位]->(p_38_单位)
#
#                     MERGE (p_38_备注_注意事项_:备注_注意事项_ {value: '【主推，可监控告警运维，不带Windows授权】'})
#                     MERGE (t_38)-[:备注_注意事项_]->(p_38_备注_注意事项_)
#
#                     MERGE (p_38_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_38)-[:模板名称]->(p_38_模板名称)
#
#                     MERGE (p_38_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_38)-[:source_file]->(p_38_source_file)
#
#                     MERGE (p_38_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_38)-[:source_sheet]->(p_38_source_sheet)
#
#             MERGE (t_39:设备名称 {name: '融合会议主机'})
#             MERGE (t_39)-[:设备名称]->(s)
#
#                     MERGE (p_39_物料编码:物料编码 {value: '1100000670.0'})
#                     MERGE (t_39)-[:物料编码]->(p_39_物料编码)
#
#                     MERGE (p_39_序号:序号 {value: '2'})
#                     MERGE (t_39)-[:序号]->(p_39_序号)
#
#                     MERGE (p_39_品牌:品牌 {value: 'IPS'})
#                     MERGE (t_39)-[:品牌]->(p_39_品牌)
#
#                     MERGE (p_39_型号:型号 {value: 'MT100W'})
#                     MERGE (t_39)-[:型号]->(p_39_型号)
#
#                     MERGE (p_39_ERP型号:ERP型号 {value: 'MT100W'})
#                     MERGE (t_39)-[:ERP型号]->(p_39_ERP型号)
#
#                     MERGE (p_39_规格:规格 {value: '硬件参数：
# CPU：Intel i5，四核8线程，主频2.4GHz
# 内存：8GB
# 硬盘：m.2 SSD240GB
# 网络：1G网络
# 系统：Windows 10
# HDMI IN：1×HDMI 4K @60fps输入
# HDMI OUT：4×HDMI 4K @60fps 输出 独立显示
# 扩展模块：支持WIFI、蓝牙、AP模块
# 供电：DC 12V 电源适配器
# 颜色：黑色钣金机身
# 尺寸：深168mm、宽180mm、高44.5mm
# ★内置Windows 10企业版正版激活码
#
# 功能参数：
# 兼容华为、腾讯会议、ZOOM、CISCO、Polycomm、小鱼、亿联、钉钉多种云视频会议平台；
# 支持视频会议的一键入会、扫码入会、信息发布；
# 可监控主机CPU、内存、磁盘使用等情况，且可异常告警；
# 会议开始前，可自动开会议设备，并可联动唤醒电视（电视需支持CEC功能）
# 支持ezcontrol监控总线，实现零编码功能配置'})
#                     MERGE (t_39)-[:规格]->(p_39_规格)
#
#                     MERGE (p_39_产地:产地 {value: '中国'})
#                     MERGE (t_39)-[:产地]->(p_39_产地)
#
#                     MERGE (p_39_数量:数量 {value: '5.0'})
#                     MERGE (t_39)-[:数量]->(p_39_数量)
#
#                     MERGE (p_39_单位:单位 {value: '台'})
#                     MERGE (t_39)-[:单位]->(p_39_单位)
#
#                     MERGE (p_39_备注_注意事项_:备注_注意事项_ {value: '【主推，可监控告警运维，带Windows 10企业版授权】
# 1、配单时需搭配融合会议控制器软件【ezCloud SWA30003】一起使用
# 2、Windows授权码为企业版
# 3、上机架需要绑带或魔术贴'})
#                     MERGE (t_39)-[:备注_注意事项_]->(p_39_备注_注意事项_)
#
#                     MERGE (p_39_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_39)-[:模板名称]->(p_39_模板名称)
#
#                     MERGE (p_39_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_39)-[:source_file]->(p_39_source_file)
#
#                     MERGE (p_39_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_39)-[:source_sheet]->(p_39_source_sheet)
#
#             MERGE (t_40:设备名称 {name: '融合会议控制器软件'})
#             MERGE (t_40)-[:设备名称]->(s)
#
#                     MERGE (p_40_物料编码:物料编码 {value: '1100000680.0'})
#                     MERGE (t_40)-[:物料编码]->(p_40_物料编码)
#
#                     MERGE (p_40_序号:序号 {value: '3'})
#                     MERGE (t_40)-[:序号]->(p_40_序号)
#
#                     MERGE (p_40_品牌:品牌 {value: 'ezCloud'})
#                     MERGE (t_40)-[:品牌]->(p_40_品牌)
#
#                     MERGE (p_40_型号:型号 {value: 'V2.0'})
#                     MERGE (t_40)-[:型号]->(p_40_型号)
#
#                     MERGE (p_40_ERP型号:ERP型号 {value: 'SWA30003'})
#                     MERGE (t_40)-[:ERP型号]->(p_40_ERP型号)
#
#                     MERGE (p_40_规格:规格 {value: '支持展示会议室预约信息列表，可快速查看会议室当前会议，及下一场和上一场会议；
#  支持视频会议一键入会，无需用户主动拨号，支持：腾讯会议、华为云会议、钉钉会议、ZOOM（瞩目）；
#  支持展示第三方会议系统的投屏码，如腾讯会议等；
#  支持控制二维码展示，通过手机扫码，操控会议控制器，如一键入会、静音、摄像头开启关闭等；
#  支持个人版第三方会议应用的自动登录和会后自动登出，如个人版飞书、个人版腾讯会议等；
#  支持将HDMI输入信号共享给第三方个人版视频会议应用，如个人版飞书、个人版腾讯会议等；
#  支持更换信息发布的壁纸；
#  支持系统状态监测，包括：CPU、内存、磁盘、网络等状态；
#  支持windows10操作系统；'})
#                     MERGE (t_40)-[:规格]->(p_40_规格)
#
#                     MERGE (p_40_产地:产地 {value: '中国'})
#                     MERGE (t_40)-[:产地]->(p_40_产地)
#
#                     MERGE (p_40_数量:数量 {value: '5.0'})
#                     MERGE (t_40)-[:数量]->(p_40_数量)
#
#                     MERGE (p_40_单位:单位 {value: '套'})
#                     MERGE (t_40)-[:单位]->(p_40_单位)
#
#                     MERGE (p_40_备注_注意事项_:备注_注意事项_ {value: '1、默认配合IPS MT系列主机；
# 2、非IPS品牌，核心价翻倍；'})
#                     MERGE (t_40)-[:备注_注意事项_]->(p_40_备注_注意事项_)
#
#                     MERGE (p_40_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_40)-[:模板名称]->(p_40_模板名称)
#
#                     MERGE (p_40_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_40)-[:source_file]->(p_40_source_file)
#
#                     MERGE (p_40_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_40)-[:source_sheet]->(p_40_source_sheet)
#
#             MERGE (t_41:设备名称 {name: '融合会议主机支架'})
#             MERGE (t_41)-[:设备名称]->(s)
#
#                     MERGE (p_41_物料编码:物料编码 {value: '1100000681.0'})
#                     MERGE (t_41)-[:物料编码]->(p_41_物料编码)
#
#                     MERGE (p_41_序号:序号 {value: '4'})
#                     MERGE (t_41)-[:序号]->(p_41_序号)
#
#                     MERGE (p_41_品牌:品牌 {value: 'IPS'})
#                     MERGE (t_41)-[:品牌]->(p_41_品牌)
#
#                     MERGE (p_41_型号:型号 {value: 'MT902'})
#                     MERGE (t_41)-[:型号]->(p_41_型号)
#
#                     MERGE (p_41_ERP型号:ERP型号 {value: 'MT902'})
#                     MERGE (t_41)-[:ERP型号]->(p_41_ERP型号)
#
#                     MERGE (p_41_规格:规格 {value: '融合会议主机支架，支持桌面隐藏安装，墙装'})
#                     MERGE (t_41)-[:规格]->(p_41_规格)
#
#                     MERGE (p_41_产地:产地 {value: '中国'})
#                     MERGE (t_41)-[:产地]->(p_41_产地)
#
#                     MERGE (p_41_数量:数量 {value: '0.0'})
#                     MERGE (t_41)-[:数量]->(p_41_数量)
#
#                     MERGE (p_41_单位:单位 {value: '台'})
#                     MERGE (t_41)-[:单位]->(p_41_单位)
#
#                     MERGE (p_41_备注_注意事项_:备注_注意事项_ {value: '桌下安装，配合MT100、MT100W'})
#                     MERGE (t_41)-[:备注_注意事项_]->(p_41_备注_注意事项_)
#
#                     MERGE (p_41_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_41)-[:模板名称]->(p_41_模板名称)
#
#                     MERGE (p_41_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_41)-[:source_file]->(p_41_source_file)
#
#                     MERGE (p_41_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_41)-[:source_sheet]->(p_41_source_sheet)
#
#             MERGE (t_42:设备名称 {name: '网络及辅材'})
#             MERGE (t_42)-[:设备名称]->(s)
#
#                     MERGE (p_42_序号:序号 {value: 'E'})
#                     MERGE (t_42)-[:序号]->(p_42_序号)
#
#                     MERGE (p_42_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_42)-[:模板名称]->(p_42_模板名称)
#
#                     MERGE (p_42_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_42)-[:source_file]->(p_42_source_file)
#
#                     MERGE (p_42_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_42)-[:source_sheet]->(p_42_source_sheet)
#
#             MERGE (t_43:设备名称 {name: '网络交换机'})
#             MERGE (t_43)-[:设备名称]->(s)
#
#                     MERGE (p_43_序号:序号 {value: '1'})
#                     MERGE (t_43)-[:序号]->(p_43_序号)
#
#                     MERGE (p_43_品牌:品牌 {value: 'HUAWEI'})
#                     MERGE (t_43)-[:品牌]->(p_43_品牌)
#
#                     MERGE (p_43_型号:型号 {value: 'S5720-28P-PWR-LI-AC'})
#                     MERGE (t_43)-[:型号]->(p_43_型号)
#
#                     MERGE (p_43_ERP型号:ERP型号 {value: 'S5720-28P-PWR-LI-AC'})
#                     MERGE (t_43)-[:ERP型号]->(p_43_ERP型号)
#
#                     MERGE (p_43_规格:规格 {value: '产品类型 :POE交换机
# 24口千兆以太网交换机，4个千兆光口
# 传输速率 :10/100/1000Mbps
# 背板带宽 :336Gbps/3.024Tbps
# 包转发率 :51Mbps/126Mbps'})
#                     MERGE (t_43)-[:规格]->(p_43_规格)
#
#                     MERGE (p_43_产地:产地 {value: '中国'})
#                     MERGE (t_43)-[:产地]->(p_43_产地)
#
#                     MERGE (p_43_数量:数量 {value: '5.0'})
#                     MERGE (t_43)-[:数量]->(p_43_数量)
#
#                     MERGE (p_43_单位:单位 {value: '台'})
#                     MERGE (t_43)-[:单位]->(p_43_单位)
#
#                     MERGE (p_43_模板名称:模板名称 {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_43)-[:模板名称]->(p_43_模板名称)
#
#                     MERGE (p_43_source_file:source_file {value: 'ezCloud.xlsx'})
#                     MERGE (t_43)-[:source_file]->(p_43_source_file)
#
#                     MERGE (p_43_source_sheet:source_sheet {value: 'SE预约+集控+虚拟分控（40间）'})
#                     MERGE (t_43)-[:source_sheet]->(p_43_source_sheet)

# %%
# from modelscope.hub.snapshot_download import snapshot_download  
#   
# model_dir = snapshot_download('DMetaSoul/Dmeta-embedding-zh', cache_dir='/mnt/d/models/embeddings', )
# Out:
# 2024-05-20 13:36:30,550 - modelscope - ERROR - Authentication token does not exist, failed to access model DMetaSoul/Dmeta-embedding-zh which may not exist or may be                 private. Please login first.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/modelscope/hub/errors.py:91, in handle_http_response(response, logger, cookies, model_id)
#      90 try:
# ---> 91     response.raise_for_status()
#      92 except HTTPError as error:
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://www.modelscope.cn/api/v1/models/DMetaSoul/Dmeta-embedding-zh/revisions
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 from modelscope.hub.snapshot_download import snapshot_download
# ----> 3 model_dir = snapshot_download('DMetaSoul/Dmeta-embedding-zh', cache_dir='/mnt/d/models/embeddings', )
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/modelscope/hub/snapshot_download.py:98, in snapshot_download(model_id, revision, cache_dir, user_agent, local_files_only, cookies, ignore_file_pattern)
#      96 if cookies is None:
#      97     cookies = ModelScopeConfig.get_cookies()
# ---> 98 revision_detail = _api.get_valid_revision_detail(
#      99     model_id, revision=revision, cookies=cookies)
#     100 revision = revision_detail['Revision']
#     102 snapshot_header = headers if 'CI_TEST' in os.environ else {
#     103     **headers,
#     104     **{
#     105         'Snapshot': 'True'
#     106     }
#     107 }
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/modelscope/hub/api.py:497, in HubApi.get_valid_revision_detail(self, model_id, revision, cookies)
#     493 current_timestamp = int(round(datetime.datetime.now().timestamp()))
#     494 # for active development in library codes (non-release-branches), release_timestamp
#     495 # is set to be a far-away-time-in-the-future, to ensure that we shall
#     496 # get the master-HEAD version from model repo by default (when no revision is provided)
# --> 497 all_branches_detail, all_tags_detail = self.get_model_branches_and_tags_details(
#     498     model_id, use_cookies=False if cookies is None else cookies)
#     499 all_branches = [x['Revision'] for x in all_branches_detail] if all_branches_detail else []
#     500 all_tags = [x['Revision'] for x in all_tags_detail] if all_tags_detail else []
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/modelscope/hub/api.py:577, in HubApi.get_model_branches_and_tags_details(self, model_id, use_cookies)
#     574 path = f'{self.endpoint}/api/v1/models/{model_id}/revisions'
#     575 r = self.session.get(path, cookies=cookies,
#     576                      headers=self.builder_headers(self.headers))
# --> 577 handle_http_response(r, logger, cookies, model_id)
#     578 d = r.json()
#     579 raise_on_error(d)
#
# File ~/miniconda/envs/agent_py11/lib/python3.11/site-packages/modelscope/hub/errors.py:98, in handle_http_response(response, logger, cookies, model_id)
#      94     logger.error(
#      95         f'Authentication token does not exist, failed to access model {model_id} which may not exist or may be \
#      96         private. Please login first.')
#      97 message = _decode_response_error(response)
# ---> 98 raise HTTPError('Response details: %s, Request id: %s' %
#      99                 (message, get_request_id(response))) from error
#
# HTTPError: Response details: {'Code': 10010205001, 'Message': '获取模型版本失败，信息：record not found', 'RequestId': '93b22f05-2de3-4989-ac30-df4fa8f4cc16', 'Success': False}, Request id: af2f43444d7b4d7ebb45238d0b6256f9

# %%
# !pip install transformers
from transformers import AutoModel
from numpy.linalg import norm

cos_sim = lambda a,b: (a @ b.T) / (norm(a)*norm(b))
model = AutoModel.from_pretrained('/mnt/d/models/embeddings/jinaai/jina-embeddings-v2-base-zh/', trust_remote_code=True) # trust_remote_code is needed to use the encode method
embeddings = model.encode(['How is the weather today?', '今天天气怎么样?'])
print(cos_sim(embeddings[0], embeddings[1]))
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: transformers in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (4.41.0)
# Requirement already satisfied: filelock in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from transformers) (0.23.0)
# Requirement already satisfied: numpy>=1.17 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from requests->transformers) (2024.2.2)
# 0.7860607

# %%
# !pip install -U sentence-transformers
from sentence_transformers import SentenceTransformer
from numpy.linalg import norm

cos_sim = lambda a,b: (a @ b.T) / (norm(a)*norm(b))
model = SentenceTransformer('/mnt/d/models/embeddings/jinaai/jina-embeddings-v2-base-zh/', trust_remote_code=True)
embeddings = model.encode(['How is the weather today?', '今天天气怎么样?'])
print(cos_sim(embeddings[0], embeddings[1]))
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: sentence-transformers in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (2.7.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from sentence-transformers) (4.41.0)
# Requirement already satisfied: tqdm in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from sentence-transformers) (2.3.0)
# Requirement already satisfied: numpy in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from sentence-transformers) (1.4.2)
# Requirement already satisfied: scipy in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from sentence-transformers) (1.13.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from sentence-transformers) (0.23.0)
# Requirement already satisfied: Pillow in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from sentence-transformers) (10.3.0)
# Requirement already satisfied: filelock in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.2.0)
# Requirement already satisfied: packaging>=20.9 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.11.0)
# Requirement already satisfied: sympy in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: regex!=2019.12.17 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /home/cc/miniconda/envs/agent_py11/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# 0.7860607

# %%
embeddings[0]
# Out:
# array([ 1.17582276e-01, -4.11230400e-02, -9.13661346e-02,  1.07975595e-01,
#         9.68639478e-02, -3.01627163e-03,  9.99230891e-02,  3.91312763e-02,
#         8.71287882e-02,  3.01063627e-01, -2.57130545e-02,  1.04525745e-01,
#         9.42578614e-02, -7.57045066e-03,  1.28830031e-01, -1.93333060e-01,
#        -5.31106889e-02,  6.59394190e-02, -2.49039456e-01,  2.41258815e-01,
#        -6.68691695e-02, -3.61450426e-02, -1.13201402e-02,  2.87404388e-01,
#         1.91802859e-01,  6.27591684e-02, -3.02702300e-02,  6.95308447e-02,
#        -1.63315833e-01, -7.99329132e-02, -2.42121052e-04, -9.61904824e-02,
#         9.71395001e-02,  7.18620792e-02,  1.86699867e-01, -3.65295112e-02,
#         6.21305034e-02,  1.91574141e-01,  1.09463885e-01,  5.40749282e-02,
#        -3.19882706e-02,  1.62023623e-02,  5.01649827e-02,  1.06443204e-01,
#        -1.79785118e-02, -6.52830601e-02, -5.84530570e-02,  4.02697138e-02,
#        -5.36461473e-02,  4.89265881e-02, -8.03642273e-02, -4.55682985e-02,
#        -1.33975849e-01,  6.81826919e-02,  1.25068650e-01, -1.15663871e-01,
#        -8.32680166e-02,  1.30111709e-01,  1.72320485e-01,  2.73346659e-02,
#         1.22795053e-01, -3.32417130e-01, -1.56839162e-01,  6.15106039e-02,
#        -6.32592067e-02,  1.21210530e-01, -1.05990246e-01, -2.62680762e-02,
#        -1.64528802e-01, -9.43507999e-02,  2.06082631e-02,  4.76736799e-02,
#        -1.40152812e-01, -9.95538607e-02, -2.25951463e-01, -1.02726035e-01,
#        -4.03160416e-02,  7.47470111e-02, -2.86260266e-02,  4.27525789e-02,
#        -2.62020886e-01,  2.57384479e-01,  1.44287255e-02,  1.71888486e-01,
#         1.98223069e-02,  1.17877319e-01, -6.46555945e-02,  1.04403362e-01,
#         1.23182461e-01, -1.57845318e-01,  1.86347783e-01,  2.59629916e-04,
#         2.80568480e-01, -6.24745339e-02,  7.35816061e-02, -9.94611755e-02,
#         2.05076206e-02, -1.56184239e-03,  7.11003616e-02,  1.51861072e-01,
#         1.24947608e-01,  5.30368164e-02, -1.01220772e-01, -2.10625947e-01,
#         8.50931704e-02, -1.43492460e-01,  1.60576463e-01,  5.86750992e-02,
#         5.51149668e-03, -1.75393790e-01,  1.43571630e-01,  1.20236129e-02,
#         1.55806169e-02,  9.01065245e-02,  2.33519711e-02, -3.00490186e-02,
#        -5.08449636e-02, -8.04396048e-02,  1.31458491e-01, -5.53625822e-02,
#        -8.79077911e-02,  5.64772785e-02,  1.79668874e-01,  1.69692822e-02,
#        -6.41272441e-02,  9.63629317e-03,  3.23216356e-02, -6.62248731e-02,
#        -8.47417712e-02, -1.26193300e-01,  8.34290534e-02,  1.80444255e-01,
#         2.82391727e-01,  9.23772901e-02, -5.61167747e-02, -9.48761106e-02,
#        -1.23047337e-01,  1.12930182e-02,  1.33418992e-01,  2.31209606e-01,
#        -4.82681133e-02,  1.85607031e-01, -3.12232203e-03, -9.52789262e-02,
#        -1.15845278e-01, -9.75902453e-02,  4.15744074e-02, -2.11799502e-01,
#        -1.09962910e-01, -1.97547227e-01, -1.33801162e-01, -7.18790293e-02,
#         2.86118295e-02, -1.83549598e-02,  3.38250287e-02, -1.28722563e-03,
#        -2.56025903e-02,  1.60887435e-01,  2.54278898e-01, -6.90270141e-02,
#         2.46943906e-02, -1.17758065e-01, -4.31393757e-02,  6.64390624e-02,
#         1.48642808e-01,  4.59391177e-02, -1.94395613e-02, -6.51219636e-02,
#         1.42049596e-01,  9.39277560e-02,  2.63236016e-02,  7.60018528e-02,
#        -1.09041870e-01,  2.37798557e-01,  6.98597580e-02, -2.64512375e-02,
#        -2.16782056e-02,  9.82292220e-02,  1.28654391e-01, -1.32892609e-01,
#         2.45599095e-02, -1.15191758e-01, -4.41982783e-02, -1.80591382e-02,
#        -6.27913885e-03,  2.41586342e-02, -3.01433593e-01, -1.50625721e-01,
#        -2.70800978e-01,  7.83494860e-02, -8.84362012e-02, -4.15796340e-02,
#         5.85054979e-02, -1.48637518e-01, -3.70018147e-02, -1.70538262e-01,
#        -8.02705064e-02, -1.61758274e-01,  5.14661968e-02, -4.74607274e-02,
#         1.60519660e-01,  8.04673135e-02, -1.81058854e-01,  4.07006405e-02,
#        -2.30689198e-01,  6.13174820e-03,  1.23273112e-01, -4.60471772e-02,
#         1.31251648e-01,  8.77767652e-02, -2.86340207e-01, -2.30056554e-01,
#         1.38444334e-01,  1.34727275e-02,  1.22677132e-01,  5.97460233e-02,
#        -1.74988747e-01,  5.80395907e-02,  5.68049997e-02, -3.11597213e-02,
#         3.16218808e-02, -2.36774206e-01, -1.74130544e-01, -1.02834301e-02,
#         4.00628187e-02, -5.76928742e-02,  1.23070247e-01,  1.13885321e-01,
#        -4.36993781e-03,  3.36536542e-02,  1.70052737e-01,  8.23590904e-02,
#        -2.44680922e-02,  2.67219692e-02,  2.61375755e-02,  1.96253642e-01,
#        -1.41318962e-01, -2.38941222e-01, -9.48684216e-02, -2.26371109e-01,
#        -1.26189634e-01,  6.37831762e-02,  5.59369475e-02,  6.46720231e-02,
#        -4.00326848e-02,  5.92930987e-02, -1.51405752e-01,  1.65973827e-02,
#         2.35349536e-01, -5.80283776e-02, -2.76762962e-01,  1.64997131e-02,
#        -4.84949276e-02,  4.64302525e-02,  1.49442349e-02,  1.46999896e-01,
#         9.49813426e-02, -4.08859029e-02, -7.45506883e-02,  9.86389518e-02,
#         1.08793050e-01, -1.73013717e-01,  1.19869091e-01,  4.65990193e-02,
#         1.03702307e-01, -1.54888052e-02, -2.61055201e-01, -9.35721844e-02,
#         4.99835387e-02, -9.24059749e-02, -5.84611148e-02,  1.57850266e-01,
#         2.42944807e-01,  4.68914062e-02,  1.23242266e-01, -1.82502657e-01,
#        -8.47329795e-02, -5.90948686e-02, -6.30592853e-02, -3.78860533e-02,
#         5.94458655e-02,  1.33264005e-01,  2.55976379e-01, -1.72800779e-01,
#        -4.43975069e-02, -1.64824631e-02,  3.29950452e-02,  5.00156395e-02,
#         1.00608617e-01, -8.32647160e-02, -2.25580841e-01,  4.65602502e-02,
#        -3.14253429e-03, -6.29084855e-02,  1.27037406e-01, -1.25606079e-03,
#         6.87696859e-02,  4.33939919e-02, -3.52180824e-02,  2.93020271e-02,
#        -4.68901768e-02, -1.01510277e-02,  5.73662221e-02, -1.29674122e-01,
#        -1.69227898e-01,  2.13680509e-02, -6.64340914e-04,  7.77997524e-02,
#        -6.42287582e-02,  4.69861105e-02,  1.39749777e-02,  7.18228295e-02,
#         2.09358856e-01,  7.60653317e-02,  7.84129128e-02, -7.76672438e-02,
#        -5.46446741e-02, -1.50570139e-01, -1.31941363e-01,  2.48597562e-01,
#        -1.21165186e-01,  1.81996435e-01,  4.37154770e-02, -8.55407119e-02,
#        -3.49990875e-02, -8.43259767e-02,  5.88747710e-02,  1.78860463e-02,
#         6.06695786e-02, -1.99308783e-01,  2.70027332e-02,  3.32488157e-02,
#         3.09561705e-03, -8.95133168e-02, -1.41806498e-01,  8.98488835e-02,
#         1.07957542e-01, -4.37551253e-02, -1.49533570e-01,  1.21995006e-02,
#        -1.05631568e-01,  1.58145472e-01, -2.86833867e-02,  1.76488981e-01,
#        -8.13205093e-02, -1.57553360e-01, -2.70864516e-02,  6.01791590e-02,
#        -1.08977228e-01, -1.97634608e-01,  9.87078622e-03,  3.58991511e-02,
#         1.76132649e-01, -9.16699171e-02, -4.23417538e-02,  1.02896884e-01,
#         1.42761171e-01, -2.05180608e-02, -2.07193941e-01,  5.66316657e-02,
#        -6.72657713e-02, -8.89931098e-02, -8.86081159e-02,  8.95371139e-02,
#        -2.26620380e-02,  1.19127221e-01,  1.66485250e-01,  9.78956521e-02,
#         3.11898179e-02,  5.79620525e-02, -3.25885341e-02, -1.05901316e-01,
#        -1.35213286e-01,  1.32558942e-01,  2.03824818e-01, -4.12700139e-03,
#        -1.85246408e-01, -1.37270615e-01, -2.02720463e-01, -4.64509875e-02,
#         1.73488915e-01,  8.60878080e-02,  4.12397422e-02,  2.27844119e-02,
#         1.27287567e-01,  1.67224869e-01,  2.93195136e-02, -1.01956442e-01,
#        -5.69234043e-02, -1.73967704e-02, -1.13536909e-01, -2.95089297e-02,
#        -1.25651732e-01,  5.12641408e-02, -4.87037599e-02, -1.61678568e-02,
#        -1.02887787e-01, -1.85479969e-01,  6.57741800e-02, -1.16028920e-01,
#        -2.10967258e-01, -1.47277862e-01,  1.15509309e-01,  3.20200920e-02,
#        -9.24964920e-02, -1.51955128e-01, -5.36667593e-02, -4.08033729e-02,
#         1.51768789e-01, -2.34454423e-02,  1.06384948e-01, -7.31513947e-02,
#        -7.57984295e-02,  2.26314366e-02, -1.01918198e-01, -6.90885559e-02,
#         9.35809389e-02,  2.52099603e-01,  2.07654666e-03,  3.04460451e-02,
#         2.90241279e-02, -2.48077899e-01,  6.97672591e-02,  5.72028793e-02,
#        -1.10944562e-01, -8.86312162e-04, -9.28186029e-02,  2.96112120e-01,
#         1.73158705e-01,  1.21053077e-01, -3.52867693e-02, -1.86970815e-01,
#         2.13868860e-02,  3.71588729e-02, -1.50087193e-01, -1.45791307e-01,
#        -8.80343746e-03,  2.82701049e-02,  2.37162367e-01,  1.77418649e-01,
#         2.25655492e-02,  1.47256702e-01, -1.34676665e-01,  3.41936320e-01,
#         1.96162254e-01, -2.08932877e-01, -1.35190219e-01,  8.89749080e-02,
#        -2.50882924e-01,  3.98234054e-02,  8.26778039e-02,  3.87080982e-02,
#         1.28392577e-01, -1.52761072e-01, -1.99606836e-01,  4.31337170e-02,
#         2.53579557e-01, -1.01902813e-01,  3.52392197e-02,  1.30187333e-01,
#        -7.80502558e-02, -3.86128039e-03,  1.27606541e-01,  4.17810977e-02,
#         1.16916113e-02,  1.68903321e-01,  1.29893675e-01, -3.76416743e-02,
#        -7.06359744e-02,  1.13572450e-02,  8.08436424e-02, -9.98496860e-02,
#        -1.64880782e-01,  8.28763396e-02, -1.71342894e-01,  2.50313699e-01,
#         8.32492784e-02,  1.08329542e-01, -1.14121109e-01,  5.16629368e-02,
#        -2.75740862e-01,  1.67405959e-02,  4.57312942e-01, -5.26107624e-02,
#        -3.28141777e-03,  6.45366013e-02, -5.30586354e-02,  1.27935618e-01,
#        -4.30603474e-02,  2.95811370e-02,  3.85356620e-02, -9.06933472e-02,
#        -5.61431423e-02,  1.28349468e-01,  5.03322817e-02,  8.43388066e-02,
#        -1.71387926e-01, -1.15294799e-01,  8.80173445e-02,  6.06986918e-02,
#         3.22932452e-02, -2.70224333e-01,  2.92455405e-02, -4.02082829e-03,
#        -6.03294782e-02,  1.47475481e-01,  6.15625232e-02, -2.83554345e-02,
#        -8.55004601e-03,  8.57341066e-02, -3.17506790e-02, -1.55036291e-03,
#        -2.51444541e-02, -1.93916023e-01, -3.49113084e-02, -1.96628898e-01,
#         2.70812750e-01, -4.92389873e-02, -2.44132224e-02, -2.08100021e-01,
#         2.17834651e-01,  4.53786552e-02,  4.57455143e-02, -4.56881225e-02,
#         1.11243442e-01,  1.51113912e-01,  6.70347735e-02,  7.14110862e-03,
#         8.19280893e-02, -1.38721734e-01, -7.60742798e-02,  6.27845526e-02,
#         2.36607149e-01, -1.63840383e-01,  9.09913853e-02,  5.13463840e-02,
#        -1.50244743e-01, -3.78838703e-02,  2.93374192e-02,  1.72707930e-01,
#         3.02568860e-02, -2.07118824e-01,  6.55893907e-02,  1.13118574e-01,
#         6.60450608e-02,  3.44980419e-01, -5.54185361e-02, -1.61762536e-01,
#        -3.21708739e-01,  1.69798926e-01, -6.28723428e-02, -2.42978022e-01,
#        -9.50163901e-02,  1.64610833e-01,  2.22331613e-01,  4.12730463e-02,
#        -1.76359136e-02,  2.53353417e-01, -2.59588175e-02, -8.58489498e-02,
#        -2.31633127e-01, -2.12699860e-01,  1.91949666e-01,  4.71489280e-02,
#        -1.08137116e-01, -7.73348613e-03,  8.89069140e-02, -1.08265325e-01,
#         6.32845536e-02, -4.59971279e-02, -3.99043486e-02, -4.80570085e-02,
#         2.54204303e-01,  2.14038119e-02,  4.95923422e-02,  1.45772129e-01,
#        -1.14527985e-01, -1.08177781e-01,  1.51929557e-01, -1.09866619e-01,
#        -1.01521216e-01, -1.39951222e-02, -3.88917699e-02,  8.77568275e-02,
#         2.20697746e-01, -4.10973430e-02,  9.37997848e-02, -2.53478214e-02,
#        -1.02209263e-01,  7.35406578e-02, -1.79520637e-01,  7.33902156e-02,
#        -1.81235328e-01, -1.60707131e-01, -7.30775855e-03, -1.02417171e-01,
#         2.56821346e-02, -1.18215367e-01, -3.83057296e-02, -3.97537872e-02,
#         1.11024529e-02, -4.44514789e-02, -1.27195612e-01,  1.85409576e-01,
#         8.73584598e-02, -3.09253931e-01,  1.32333949e-01,  1.23957954e-02,
#         7.26777837e-02, -9.26751643e-04, -1.06064394e-01,  1.96151137e-01,
#        -1.13986522e-01, -1.55630007e-01,  7.18337819e-02, -8.25576261e-02,
#        -9.97828469e-02,  7.99555480e-02,  1.26592293e-02,  1.15638658e-01,
#         4.94443104e-02,  5.93278334e-02,  6.01399839e-02,  2.43267775e-01,
#         1.92165136e-01,  8.86248052e-02,  1.81027159e-01, -1.54474646e-01,
#         1.79612599e-02, -8.09398666e-02, -2.85879131e-02, -7.66925793e-03,
#         3.25680822e-02,  1.08190060e-01,  3.60038877e-02,  8.66161287e-03,
#         1.77248329e-01,  5.82194794e-03, -5.42165861e-02, -2.56924108e-02,
#         1.16695486e-01, -9.71648172e-02, -1.49045750e-01, -8.10405798e-03,
#        -7.04629486e-03, -1.09332874e-01,  4.52438071e-02,  2.27913231e-01,
#        -1.14100225e-01, -1.56578898e-01,  5.55794835e-02,  7.34352097e-02,
#        -4.81458083e-02,  1.04619801e-01,  1.61226094e-02, -6.61564767e-02,
#         2.21689362e-02,  5.01549477e-03,  6.52202498e-03, -1.32789940e-01,
#         5.06158434e-02,  8.55799913e-02, -1.60937324e-01, -1.74897268e-01,
#        -1.83164865e-01,  6.08739927e-02, -1.14330269e-01,  1.32379174e-01,
#         2.57725656e-01,  9.52194855e-02,  1.35868490e-02, -7.52487034e-02,
#        -8.68945122e-02, -3.94938439e-02,  6.15896983e-03,  1.79067791e-01,
#         5.34947701e-02, -1.19695803e-02,  9.87248942e-02,  6.71477988e-02,
#         1.19737193e-01, -8.59524831e-02,  4.08200026e-02,  1.40416488e-01,
#         1.41994774e-01, -1.17881842e-01, -3.40325721e-02,  1.18770331e-01,
#         3.33270989e-02, -7.85162002e-02, -4.70290035e-02, -1.83784664e-01,
#        -1.96766071e-02, -1.28141269e-02,  1.45588934e-01, -2.11959794e-01,
#        -1.84067667e-01, -2.30840314e-02, -8.48281980e-02, -1.45512521e-01,
#        -1.55337140e-01,  6.45748377e-02,  3.29760201e-02,  3.43309417e-02,
#        -3.21405428e-03,  5.61922714e-02,  2.87663396e-02,  1.25059187e-01,
#        -5.79874665e-02, -1.45166874e-01,  1.80149302e-01, -1.03607275e-01,
#         5.34929801e-03,  1.88846081e-01,  5.40073290e-02, -7.89014325e-02,
#        -2.56987885e-02,  3.14790234e-02,  2.57596876e-02,  3.44327651e-02,
#         1.20949540e-02, -6.93752915e-02, -9.54683498e-02,  3.57494205e-02,
#        -7.09947348e-02, -7.76355416e-02, -8.86525735e-02,  1.72824785e-01,
#        -2.43717432e-03, -7.63941854e-02,  8.07313919e-02, -1.72798000e-02,
#        -1.65898830e-01, -8.22633877e-02,  2.36535724e-02,  3.49360295e-02,
#        -1.76657274e-01,  7.65076792e-03, -5.75063191e-02, -2.09189653e-02,
#         8.99697468e-03, -5.06780371e-02,  1.85583439e-02, -8.51534009e-02,
#         1.11376867e-01,  6.94589317e-02,  5.01127914e-02, -2.22656831e-01,
#         1.27638411e-03, -2.56716102e-01,  6.12492897e-02, -1.05034783e-01,
#        -6.16636686e-02, -2.68737406e-01,  1.76542103e-01,  4.59471270e-02,
#        -6.94314390e-02, -1.00624308e-01,  2.01237754e-06, -7.66336024e-02,
#         2.23895088e-02,  5.07473834e-02, -1.20479830e-01, -3.00075952e-03,
#         8.80425796e-02, -9.91234258e-02, -1.05858594e-01,  1.11860454e-01],
#       dtype=float32)

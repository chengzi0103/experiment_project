# %%
from experiment_project.utils.files.util import get_all_files
import pandas as pd

# %%
data_files = list(get_all_files('/mnt/d/project/zzbc/experiment_project/experiment_project/audio/data/audio'))

# %%
df = pd.read_excel(data_files[0])

# %%
df

# %%
df2 = pd.read_excel(data_files[1])
df2

# %%
df3 = pd.read_excel(data_files[2])
df3

# %%
df4 = pd.read_excel(data_files[-1])
df4

# %%
from pandasai import SmartDataframe
from pandasai.llm import OpenAI
from pandasai.helpers.openai_info import get_openai_callback
import os
openai_api_key="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"
os.environ['http_proxy'] = 'http://192.168.0.75:10809'
os.environ['https_proxy'] = 'http://192.168.0.75:10809'
excel_file_path = '/mnt/d/project/zzbc/experiment_project/experiment_project/audio/data/audio/product_list_copy.xlsx'
ez_cloud_df = pd.read_excel(excel_file_path, sheet_name='ezCloud')
ez_cloud_df
# Out:
#             物料编码  序号                               设备名称       品牌        型号  \
# 0            NaN  一、              服务端（一个项目一般配一组，如A组、B组）      NaN       NaN
# 1            NaN   A      ezCloud会议（房间数量无限制，可定制开发和系统集成）      NaN       NaN
# 2   1.100001e+09  A1                         智慧会议预约管理系统  ezCloud      V2.0
# 3   1.100001e+09  A2                       智慧会议集中控制管理系统  ezCloud      V2.0
# 4   7.000000e+09  A3                     ezCloud智慧会议云服务  ezCloud  SAAS0001
# 5   7.000000e+09  A4                          集控会议室数量授权  ezCloud  SWL20001
# 6   7.000000e+09  A5                       语音呼叫调度服务软件授权  ezCloud  SWL90002
# 7   7.000000e+09  A6                             软件定制开发       定制        定制
# 8   7.000000e+09  A7                             系统部署实施       定制        定制
# 9            NaN   B  ezCloud SE会议（仅限于40间会议室以下，不支持定制开发）      NaN       NaN
# 10  1.100001e+09  B1                         智慧会议预约管理系统  ezCloud      V2.0
# 11  1.100001e+09  B2                       智慧会议集中控制管理系统  ezCloud      V2.0
# 12  1.100001e+09  B3                       ezCloudSE加密狗  ezCloud  SWK-SE01
# 13           NaN   C                ezControl（分布式控制器软件）      NaN       NaN
# 14  1.100001e+09  C1                           智能物联控制系统  ezCloud      V2.0
# 15  7.000000e+09  C2                           虚拟分控房间授权  ezCloud  SWL30001
# 16           NaN   D               ezCloud文体版（一个馆、场配一组）      NaN       NaN
# 17  1.100001e+09  D1                       专业扩声系统智能总控平台  ezCloud      V1.0
# 18  7.000000e+09  D2                         分布式控制器现场实施       定制        定制
# 19  7.000000e+09  D3                             软件定制开发       定制        定制
# 20           NaN  二、                    客户端应用（配合物联控制硬件）      NaN
# 21           NaN   A                         分控（中控）相关应用      NaN       NaN
# 22  7.000000e+09  A1                         分布式控制器现场实施       定制        定制
# 23           NaN   B                            信息屏相关应用      NaN       NaN
# 24  1.100001e+09  B1                            智慧信息屏软件  ezCloud      V2.0
# 25  1.100001e+09  B2                          人脸识别SDK应用  ezCloud  SWA90001
# 26  1.100001e+09  B3                          智慧会议指引屏软件  ezCloud      V2.0
# 27           NaN   C                            控制屏相关应用      NaN       NaN
# 28  1.100001e+09  C1                           分布式控制器软件  ezCloud      V2.0
# 29  1.100001e+09  C2                    分布式控制器软件（含一键呼叫）  ezCloud      V2.0
# 30           NaN   D                             会议主机相关      NaN       NaN
# 31  1.100001e+09  D1                          融合会议控制器软件  ezCloud      V2.0
# 32           NaN   E                            云视频会议相关      NaN       NaN
# 33  7.000000e+09  E1                            腾讯会议云服务       腾讯  SWL90003
# 34  7.000000e+09  E2                            华为云会议服务       华为  SWL90004
#
#                   ERP型号                                                 规格  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2         SW-EZLINK-V02  支持在手机、平板、电脑等各种终端上进行空间预约，包括：大中小会议室、培训室、多功能厅、功能室...
# 3      SW-EZMANAGER-V02  支持多种场景的门禁对接，包括如海康、大华平台型智能锁，485、继电器、干节点类门锁；\n支持...
# 4              SAAS0001                        智慧会议预约管理系统和智慧会议集中控制管理系统的租用版
# 5              SWL20001                             集控会议室数量授权，每个会议室需配置1个授权
# 6              SWL90002                            语音呼叫调度服务软件授权，配合一键呼叫功能使用
# 7                    定制  定制开发项包括但不限于：OA流程审批对接、用户及组织架构自动同步、企业级统一用户认证登录、第...
# 8                    定制  ezCloud服务集群部署实施，基于linux操作系统、k8s容器部署方案，部署微服务包括预...
# 9                   NaN                                                NaN
# 10     SW-EZLINK-SE-V02  支持在手机、电脑等多种终端上进行会议预约、预约信息查看，可展示个人会议日历，会议室空闲一览表...
# 11  SW-EZMANAGER-SE-V02  支持在内网环境下，对会议室内设备进行实时远程控制和远程设备监测，方便运维人员在无法到达会议室...
# 12             SWK-SE01  ezCloud SE系统的加密U盘，如果同时配了SW-EZLINK-SE-V02和SW-EZ...
# 13                  NaN                                                NaN
# 14     SW-EZCONTROL-V02  基于Web的Admin管理控制界面，采用图形化的设备配置，标准实施零编程，定制需求低代码实现...
# 15             SWL30001                             集控会议室数量授权，每个会议室需配置1个授权
# 16                  NaN                                                NaN
# 17       SW-EZCLOUD-V01  文体管控平台是专门针对体育场馆设计和开发的，且位于硬件系统之上的AIoT物联行业软硬一体化系...
# 18                   定制                                  分布式控制器现场实施，一个场馆一套
# 19                   定制                        软件定制化开发需评估，如：实景UI界面、3D人机交互等
# 20                                                                     NaN
# 21                  NaN                                                NaN
# 22                   定制  DP系列控制器 会议室操控界面实施服务\n1. 根据会议室真实场景编程，定制开发会议室控制界...
# 23                  NaN                                                NaN
# 24             SWA10002  支持会议室预约信息展示，信息包含会议室名称、房间号、企业Logo、日期时间、最近3天的预约信...
# 25             SWA90001                   人脸识别应用SDK授权，配合智慧会议指引屏软件，提供人脸识别功能
# 26             SWA10004  支持集中展示楼层所有会议室的预约信息、会议室分布图；\n支持展示当前位置，支持用户交互，点击...
# 27                  NaN                                                NaN
# 28             SWA30001  极简的用户控制界面设计，用户三分钟上手，具有浅色和深色模式，多种主题可供选择，适配各种使用场...
# 29             SWA30002  极简的用户控制界面设计，用户三分钟上手，具有浅色和深色模式，多种主题可供选择，适配各种使用场...
# 30                  NaN                                                NaN
# 31             SWA30003  支持展示会议室预约信息列表，可快速查看会议室当前会议，及下一场和上一场会议；\n支持视频会议...
# 32                  NaN                                                NaN
# 33             SWL90003   可自行选择以下产品：\n1.用户数（10个起）\n2.虚拟会议室（10个起卖）：50方、1...
# 34             SWL90004  可自行选择以下产品：\n1.会议并发数（2个起）\n2.云会议室：10方、50方、100方、...
#
#      产地   数量   单位  ...                                           备注（注意事项）  \
# 0   NaN  NaN  NaN  ...                                                NaN
# 1   NaN  NaN  NaN  ...                                                NaN
# 2    中国  0.0    套  ...      1、规格参数为全集，可根据项目需要删减，参考：ezCloud标底参数、功能说明及注意事项
# 3    中国  0.0    套  ...      1、规格参数为全集，可根据项目需要删减，参考：ezCloud标底参数、功能说明及注意事项
# 4    中国  0.0    套  ...                                 目前仅用于体验点和物联集控DEMO箱
# 5    中国  0.0    套  ...  1、仅用于会议室数量增补使用\n2、首次购买，会议室授权会包含在智慧会议预约管理系统和智慧会...
# 6    中国  0.0    套  ...            1、配置数量取决于呼叫中心数量，比如一层楼一个服务呼叫中心，共4层楼，则配4个
# 7    中国  0.0   人天  ...                                   1、定制开发人天取决于定制工作量
# 8    中国  0.0    套  ...                                  【甲供服务器或虚拟机，需增加此项】
# 9   NaN  NaN  NaN  ...                                                NaN
# 10   中国  0.0    套  ...  1、【注意】需配置ezCloudSE加密狗（型号SWK-SE01，料号1100000960）...
# 11   中国  0.0    套  ...  1、【注意】需配置ezCloudSE加密狗（型号SWK-SE01，料号1100000960）...
# 12   中国  0.0    个  ...       1、SW-EZLINK-SE-V02和SW-EZMANAGER-SE-V02可共用1个；
# 13  NaN  NaN  NaN  ...                                                NaN
# 14   中国  0.0    套  ...  1、默认配合IPS DP120E虚拟分控使用；\n2、可配合IPS MS100集控主机使用；...
# 15   中国  0.0    套  ...                                     1、仅用于会议室数量增补使用
# 16  NaN  NaN  NaN  ...                                                NaN
# 17   中国  0.0    套  ...      1、【注意】需配置ezCloudSE加密狗（型号SWK-SE01，料号1100000960
# 18   中国  0.0    间  ...                            1、实施费可合并至SW-EZCLOUD-V01
# 19   中国  0.0   人天  ...                                       1、需软件部门评估工作量
# 20  NaN  NaN  NaN  ...                                                NaN
# 21  NaN  NaN  NaN  ...                                                NaN
# 22   中国  0.0    间  ...  1、厂家支持实施，需增加此项；\n2、如合作伙伴交付，无需此项；\n3、实施费可合并至SWA...
# 23  NaN  NaN  NaN  ...                                                NaN
# 24   中国  0.0    套  ...               1、默认配合IPS CTS系列智慧屏；\n2、非IPS品牌，核心价翻倍；
# 25   中国  0.0    套  ...                                       【如需人脸识别功能必配】
# 26   中国  0.0    套  ...                                  1、主要用于会议楼层或会议中心指引
# 27  NaN  NaN  NaN  ...                                                NaN
# 28   中国  0.0    套  ...  1、10寸及以上控制屏配置；\n2、默认配合IPS CTS系列智慧屏；\n3、非IPS品牌，...
# 29   中国  0.0    套  ...  1、下单时去掉“（含一键呼叫）”\n2、10寸及以上控制屏配置；\n3、默认配合IPS CT...
# 30  NaN  NaN  NaN  ...                                                NaN
# 31   中国  0.0    套  ...                 1、默认配合IPS MT系列主机；\n2、非IPS品牌，核心价翻倍；
# 32  NaN  NaN  NaN  ...                                                NaN
# 33   中国  0.0    套  ...  包含企业版和商业版\n企业版本必须要购买最少10个用户数、10个虚拟会议室\n商业版无限制，...
# 34   中国  0.0    套  ...                                                NaN
#
#                                                  标底参数             可控标演示功能描述  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                   NaN
# 2   支持在手机、平板、电脑等各种终端上进行空间预约，包括：大中小会议室、培训室、多功能厅、功能室...  所有双星控标点均可提供演示视频、现场演示
# 3   ★支持多种场景的门禁对接，包括如海康、大华平台型智能锁，485、继电器、干节点类门锁；\n支...  所有双星控标点均可提供演示视频、现场演示
# 4                                                 NaN                   NaN
# 5                                                 NaN                   NaN
# 6                                                 NaN                   NaN
# 7                                                 NaN                   NaN
# 8                                                 NaN                   NaN
# 9                                                 NaN                   NaN
# 10  支持在手机、电脑等多种终端上进行会议预约、预约信息查看，可展示个人会议日历，会议室空闲一览表...  所有双星控标点均可提供演示视频、现场演示
# 11  支持在内网环境下，对会议室内设备进行实时远程控制和远程设备监测，方便运维人员在无法到达会议室...  所有双星控标点均可提供演示视频、现场演示
# 12                                                NaN                   NaN
# 13                                                NaN                   NaN
# 14  ★基于Web的Admin管理控制界面，采用图形化的设备配置，标准实施零编程，定制需求低代码实...  所有双星控标点均可提供演示视频、现场演示
# 15                                                NaN                   NaN
# 16                                                NaN                   NaN
# 17  文体管控平台是专门针对体育场馆设计和开发的，且位于硬件系统之上的AIoT物联行业软硬一体化系...                   NaN
# 18                                                NaN                   NaN
# 19                                                NaN                   NaN
# 20                                                NaN                   NaN
# 21                                                NaN                   NaN
# 22                                                NaN                   NaN
# 23                                                NaN                   NaN
# 24  支持会议室预约信息展示，信息包含会议室名称、房间号、企业Logo、日期时间、最近3天的预约信...  所有双星控标点均可提供演示视频、现场演示
# 25  支持集中展示楼层所有会议室的预约信息、会议室分布图；\n★支持展示当前位置，支持用户交互，点...                   NaN
# 26  支持集中展示楼层所有会议室的预约信息、会议室分布图；\n ★支持展示当前位置，支持用户交互，...  所有双星控标点均可提供演示视频、现场演示
# 27                                                NaN                   NaN
# 28  ★极简的用户控制界面设计，用户三分钟上手，具有浅色和深色模式，多种主题可供选择，适配各种使用...  所有双星控标点均可提供演示视频、现场演示
# 29  ★极简的用户控制界面设计，用户三分钟上手，具有浅色和深色模式，多种主题可供选择，适配各种使用...  所有双星控标点均可提供演示视频、现场演示
# 30                                                NaN                   NaN
# 31  ★支持展示会议室预约信息列表，可快速查看会议室当前会议，及下一场和上一场会议；\n★★支持视...  所有双星控标点均可提供演示视频、现场演示
# 32                                                NaN                   NaN
# 33                                                NaN                   NaN
# 34                                                NaN                   NaN
#
#                                                  控标说明  \
# 0                                                 NaN
# 1                                                 NaN
# 2   1、蓝凌、泛微是OA厂家，有预约模块，非专业预约系统系统，功能较难满足客户需求；\n2、DF...
# 3   1、蓝凌、泛微是OA厂家，有预约模块，非专业预约系统系统，功能较难满足客户需求；\n2、DF...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  1、蓝凌、泛微是OA厂家，有预约模块，非专业预约系统系统，功能较难满足客户需求；\n2、DF...
# 11  1、蓝凌、泛微是OA厂家，有预约模块，非专业预约系统系统，功能较难满足客户需求；\n2、DF...
# 12                                                NaN
# 13                                                NaN
# 14  1、蓝凌、泛微是OA厂家，有预约模块，非专业预约系统系统，功能较难满足客户需求；\n2、DF...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  1、蓝凌、泛微是OA厂家，有预约模块，非专业预约系统系统，功能较难满足客户需求；\n2、DF...
# 25                                                NaN
# 26  1、蓝凌、泛微是OA厂家，有预约模块，非专业预约系统系统，功能较难满足客户需求；\n2、DF...
# 27                                                NaN
# 28  1、蓝凌、泛微是OA厂家，有预约模块，非专业预约系统系统，功能较难满足客户需求；\n2、DF...
# 29  1、蓝凌、泛微是OA厂家，有预约模块，非专业预约系统系统，功能较难满足客户需求；\n2、DF...
# 30                                                NaN
# 31  1、蓝凌、泛微是OA厂家，有预约模块，非专业预约系统系统，功能较难满足客户需求；\n2、DF...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                                          可控商务条款（厂家证书）  \
# 0                                                 NaN
# 1                                                 NaN
# 2   厂家层面：高新技术企业、ISO9001质量管理体系认证\n产品层面：『国家信息安全等级保护』...
# 3   厂家层面：高新技术企业、ISO9001质量管理体系认证\n产品层面：『国家信息安全等级保护』...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  厂家层面：高新技术企业、ISO9001质量管理体系认证\n产品层面：『国家信息安全等级保护』...
# 11  厂家层面：高新技术企业、ISO9001质量管理体系认证\n产品层面：『国家信息安全等级保护』...
# 12                                                NaN
# 13                                                NaN
# 14  厂家层面：高新技术企业、ISO9001质量管理体系认证\n产品层面：『国家信息安全等级保护』...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  厂家层面：高新技术企业、ISO9001质量管理体系认证\n产品层面：『国家信息安全等级保护』...
# 25                                                NaN
# 26  厂家层面：高新技术企业、ISO9001质量管理体系认证\n产品层面：『国家信息安全等级保护』...
# 27                                                NaN
# 28  厂家层面：高新技术企业、ISO9001质量管理体系认证\n产品层面：『国家信息安全等级保护』...
# 29  厂家层面：高新技术企业、ISO9001质量管理体系认证\n产品层面：『国家信息安全等级保护』...
# 30                                                NaN
# 31  厂家层面：高新技术企业、ISO9001质量管理体系认证\n产品层面：『国家信息安全等级保护』...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                                                    案例  \
# 0                                                 NaN
# 1                                                 NaN
# 2   1、国家电网\n2、华润置地\n3、潍柴动力\n4、中国重汽\n5、厦门航空\n6、阳光保险...
# 3   1、国家电网\n2、华润置地\n3、潍柴动力\n4、中国重汽\n5、厦门航空\n6、阳光保险...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  1、国家电网\n2、华润置地\n3、潍柴动力\n4、中国重汽\n5、厦门航空\n6、阳光保险...
# 11  1、国家电网\n2、华润置地\n3、潍柴动力\n4、中国重汽\n5、厦门航空\n6、阳光保险...
# 12                                                NaN
# 13                                                NaN
# 14  1、国家电网\n2、华润置地\n3、潍柴动力\n4、中国重汽\n5、厦门航空\n6、阳光保险...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  1、国家电网\n2、华润置地\n3、潍柴动力\n4、中国重汽\n5、厦门航空\n6、阳光保险...
# 25                                                NaN
# 26  1、国家电网\n2、华润置地\n3、潍柴动力\n4、中国重汽\n5、厦门航空\n6、阳光保险...
# 27                                                NaN
# 28  1、国家电网\n2、华润置地\n3、潍柴动力\n4、中国重汽\n5、厦门航空\n6、阳光保险...
# 29  1、国家电网\n2、华润置地\n3、潍柴动力\n4、中国重汽\n5、厦门航空\n6、阳光保险...
# 30                                                NaN
# 31  1、国家电网\n2、华润置地\n3、潍柴动力\n4、中国重汽\n5、厦门航空\n6、阳光保险...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                                       推荐品牌  \
# 0                                      NaN
# 1                                      NaN
# 2   进口：快思聪、AMX、Extron\n国产：艾维创、蓝凌、泛微、DFoucs
# 3   进口：快思聪、AMX、Extron\n国产：艾维创、蓝凌、泛微、DFoucs
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10  进口：快思聪、AMX、Extron\n国产：艾维创、蓝凌、泛微、DFoucs
# 11  进口：快思聪、AMX、Extron\n国产：艾维创、蓝凌、泛微、DFoucs
# 12                                     NaN
# 13                                     NaN
# 14  进口：快思聪、AMX、Extron\n国产：艾维创、蓝凌、泛微、DFoucs
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24  进口：快思聪、AMX、Extron\n国产：艾维创、蓝凌、泛微、DFoucs
# 25  进口：快思聪、AMX、Extron\n国产：艾维创、蓝凌、泛微、DFoucs
# 26  进口：快思聪、AMX、Extron\n国产：艾维创、蓝凌、泛微、DFoucs
# 27                                     NaN
# 28  进口：快思聪、AMX、Extron\n国产：艾维创、蓝凌、泛微、DFoucs
# 29  进口：快思聪、AMX、Extron\n国产：艾维创、蓝凌、泛微、DFoucs
# 30                                     NaN
# 31  进口：快思聪、AMX、Extron\n国产：艾维创、蓝凌、泛微、DFoucs
# 32                                     NaN
# 33                                     NaN
# 34                                     NaN
#
#                                             规格单页或知识产权  \
# 0                                                 NaN
# 1                                                 NaN
# 2   第10972334号 智慧会议预约管理系统V2.0\n第4612640号 易科智能会务预约管...
# 3   第10972346号 智慧会议集中控制管理系统V2.0\n第4592791号 易科音频设备智...
# 4                                                   /
# 5                                                   /
# 6                                                   /
# 7                                                   /
# 8                                                   /
# 9                                                 NaN
# 10  第10972334号 智慧会议预约管理系统V2.0\n第4612640号 易科智能会务预约管...
# 11  第10972346号 智慧会议集中控制管理系统V2.0\n第4592791号 易科音频设备智...
# 12                                                NaN
# 13                                                NaN
# 14  第11010758号 智能物联控制系统V2.0\n第4635879号 基于ARM的智能会议中...
# 15                                                  /
# 16                                                NaN
# 17                        第10644753号 专业扩声系统智能总控平台V1.0
# 18                                                  /
# 19                                                  /
# 20                                                NaN
# 21                                                NaN
# 22                                                  /
# 23                                                NaN
# 24    第11010846号 智慧信息屏软件V2.0\n第6693114号 智能会务预约屏系统V1.0
# 25                                                  /
# 26                           第11010805号 智慧会议指引屏软件V2.0
# 27                                                NaN
# 28  第11010717号 分布式控制器软件V2.0\n第6059993号 会议室平板控制界面自适...
# 29  第11010717号 分布式控制器软件V2.0\n第6059993号 会议室平板控制界面自适...
# 30                                                NaN
# 31                           第11010847号 融合会议控制器软件V2.0
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                             宣传彩页 供货周期（天）
# 0                            NaN     NaN
# 1                            NaN     NaN
# 2   ezCloud介绍及案例彩页v20220514.pdf        1
# 3   ezCloud介绍及案例彩页v20220514.pdf        1
# 4                            NaN       1
# 5                            NaN       1
# 6                            NaN       1
# 7                            NaN    研发评估
# 8                            NaN       1
# 9                            NaN     NaN
# 10      ezCloud SE彩页v202303.pdf        1
# 11      ezCloud SE彩页v202303.pdf        1
# 12                           NaN       1
# 13                           NaN     NaN
# 14                           NaN       1
# 15                           NaN       1
# 16                           NaN     NaN
# 17                           NaN       1
# 18                           NaN       1
# 19                           NaN    研发评估
# 20                           NaN     NaN
# 21                           NaN     NaN
# 22                           NaN       1
# 23                           NaN     NaN
# 24                           NaN       1
# 25                           NaN       1
# 26                           NaN       1
# 27                           NaN     NaN
# 28                           NaN       1
# 29                           NaN       1
# 30                           NaN     NaN
# 31                           NaN       1
# 32                           NaN     NaN
# 33                           NaN       1
# 34                           NaN       1
#
# [35 rows x 22 columns]

# %%
ez_cloud_df.to_csv('/mnt/d/project/zzbc/experiment_project/experiment_project/audio/data/audio/product_list_ez_cloud.csv')

# %%
ez_cloud_df.columns
# Out:
# Index(['物料编码', '序号', '设备名称', '品牌', '型号', 'ERP型号', '规格', '产地', '数量', '单位', '单价',
#        '合价', '备注（注意事项）', '标底参数', '可控标演示功能描述', '控标说明', '可控商务条款（厂家证书）', '案例',
#        '推荐品牌', '规格单页或知识产权', '宣传彩页', '供货周期（天）'],
#       dtype='object')

# %%
llm = OpenAI(api_token=openai_api_key)

df = SmartDataframe(ez_cloud_df.iloc[2:], config={"llm": llm, "conversational": False})

# %%
response = df.chat("里面一共有哪些产品型号")
response
# Out:
# 'The product models inside are: SWA90001, SWL90003.'
